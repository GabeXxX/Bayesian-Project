# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import time
from itertools import product, groupby
import math
import scipy.stats as stats

# %%
from mpmath import mp
mp.dps = 50

# %%
def prior_kernel(s,t):
    return np.exp(-((t-s)/5)**2)+0.0001*(s==t)

def runs(a_list):
    runs_zeros = len([k for k, g in groupby(a_list) if k == 0])
    runs_ones = len([k for k, g in groupby(a_list) if k == 1])
    return runs_ones + runs_zeros

def tr(actions):
    if len(actions)<100:
        return 1
    else:
        return 1-0.02*(100-sum(actions[-100:-1]))/100

# %%
class posterior:
    def __init__(self, T, T0, x, y, K,sigma):
        self.T = T
        self.x = x
        self.y = y
        self.n = y.shape[0]
        self.g = T.shape[0]
        self.T0 = np.array(T0)
        self.sigma = sigma
        self.K = K
        self.K0 = self.get_K0()

    def get_K(self):
        return self.K

    def getter(self):
        return self.K0

    def get_K0(self):
        tau = np.where(self.T0==1)[0]
        K_tau=self.K[:, tau]
        K_tau_tau = self.K[tau[:, None], tau]
        return self.K- np.dot(np.dot(K_tau, np.linalg.inv(K_tau_tau)), K_tau.T)

    def Lx0(self,t):
        L = np.zeros(self.n)
        for i in np.arange(0,self.n):
            L[i] = np.trapz(self.K0[t, :] * self.x[i,:], self.T)
        return L

    def likelihood(self): #p(Y|T0)
        m_matrix = self.M()
        first = np.linalg.det(m_matrix) ** (-0.5)


        inv = np.linalg.inv(m_matrix)
        s11 = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),np.ones(self.n))

        syy = np.dot(np.dot(np.transpose(self.y),inv),self.y)
        s1y = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),self.y)
        b = 0.5*(syy-s1y**2/s11)

        return first/np.sqrt(s11)*(b**(-0.5*(self.n-1)))

    def R0(self,i, j):
        Ri = np.trapz(self.K0[:, :] * self.x[i, :], self.T, axis=1)
        Rij = np.trapz(Ri * self.x[j, :],self.T)
        return Rij

    def M(self):
        return np.array([[self.R0(i, j) for j in range(self.n)] for i in range(self.n)])+np.identity(self.n)

    def posterior_mean_cov(self):
        M_mat = self.M()
        inv = np.linalg.inv(M_mat)
        S11 = np.dot(np.dot(np.transpose(np.ones(M_mat.shape[0])),inv),np.ones(M_mat.shape[0]))
        SY1 = np.dot(np.dot(np.transpose(self.y),inv),np.ones(M_mat.shape[0]))

        def m(t):
            mean = np.dot(np.dot(np.transpose(self.Lx0(t)), inv), (self.y - (SY1 / S11) * np.ones(len(self.y))))
            return mean
        def Kstar(s,t):
            cov = (self.sigma**2)*(self.K0[s,t] - np.dot(np.dot(np.transpose(self.Lx0(s)),inv),self.Lx0(t)))
            return cov

        m = np.fromfunction(np.vectorize(lambda t: m(t)), (self.g,), dtype=int)
        C = np.fromfunction(np.vectorize(lambda t, s: Kstar(s,t)), (self.g,self.g), dtype=int)
        return m,C

    def only_mean(self):
        inv = np.linalg.inv(self.M())
        def m(t):
            mean = np.dot(np.dot(np.transpose(self.Lx0(t)),inv),self.y)
            return mean
        m = np.fromfunction(np.vectorize(lambda t: m(t)), (self.g,), dtype=int)
        return m

    def fitted_values(self):
        m = self.only_mean()
        return np.fromfunction(np.vectorize(lambda i: np.trapz(self.x[i,:]*m,self.T)), (self.n,), dtype=int)

# %%
class T0_est:
    def __init__(self, T, x, y,K,sigma,alpha,n_sim=1000,burn=0):
        self.T= T
        self.x=x
        self.y=y
        self.sigma=sigma
        self.alpha=alpha
        self.n_sim=n_sim
        self.burn=burn
        self.n = y.shape[0]
        self.g = T.shape[0]
        self.K=K
        self.count = 0

        self.T0_init = np.array([0, 1] * (self.g // 2))
        self.action = []

    def chain_builder(self):
        chain = [self.T0_init]
        for i in range(self.n_sim):
            curr=chain[-1]
            chain.append(self.next_T0(curr))
            print('Current Number of Points in T0: '+str(sum(chain[-1])))
        return chain[self.burn:]


    def next_T0(self,current):
        new = self.candidate(current)
        rate=self.acceptance_rate(current,new)
        print('Acceptance Rate = '+str(rate)+'\n')
        treshold = tr(self.action)

        self.count = self.count + 1
        print(str(self.count)+'/'+str(self.n_sim) + ' in findind T0...\n')
        if rate>=treshold:
            self.action.append(1)
            return new

        else:
            self.action.append(0)
            return current

    def candidate(self,old):
        new=old.copy()
        coin = np.random.uniform(0,1,1)

        if coin<0.2: #split
            choices = [i for i in range(1,len(old) - 1) if old[i-1] == 1 and old[i] == 1 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                splitting_point = choice
                new[splitting_point]=0

        if (coin>=0.2) and (coin<0.4): #right removal
            choices = [i for i in range(0,len(old)-1) if old[i] == 1 and old[i + 1] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0

        if (coin>=0.4) and (coin<0.6): #left removal
            choices = [i+1 for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0

        if (coin>=0.6) and (coin<0.8): #right add
            choices = [i for i in range(1,len(old)) if old[i-1] == 1 and old[i] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        if coin>=0.8: #left add
            choices = [i for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        if sum(old)==0:
            choice = np.random.choice(range(len(old)))
            new[choice]=1
        return new


    def acceptance_rate(self,current,new):
        prior = self.PT0(current)
        prior_new = self.PT0(new)
        likl = posterior(self.T,current,self.x,self.y,self.K,self.sigma).likelihood()
        likl_new =posterior(self.T,new,self.x,self.y,self.K,self.sigma).likelihood()
        return (likl_new*prior_new)/(likl*prior)


    def PT0(self,current):
        r=runs(current)
        return mp.exp(-r*self.alpha)

# %%
sigma = 10
T = np.linspace(1, 288, 288)
K = np.fromfunction(np.vectorize(lambda s, t: prior_kernel(T[s], T[t])), (T.shape[0], T.shape[0]), dtype=int)

# %%
df = pd.read_csv('/kaggle/input/average-curves/average_curves.csv', index_col='idx')
df
# Out:
#                     0          1          2          3          4          5  \
# idx
# pat_number   0.000000   1.000000   2.000000   3.000000   4.000000   5.000000
# severity     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# constancy    1.000000   1.000000   2.000000   1.000000   2.000000   2.000000
# age         58.000000  59.000000  62.000000  65.000000  65.000000  70.000000
# gender       1.000000   2.000000   2.000000   1.000000   1.000000   2.000000
# ...               ...        ...        ...        ...        ...        ...
# 283         -0.981659  -1.076615  -1.332550  -1.058805  -0.923807  -1.109480
# 284         -0.993531  -1.078280  -1.332549  -1.044116  -0.923762  -1.109441
# 285         -0.997926  -1.079618  -1.332558  -1.019142  -0.923818  -1.109399
# 286         -0.998365  -1.076988  -1.332594  -1.004871  -0.923853  -1.109362
# 287         -0.999580  -1.057946  -1.332677  -1.004709  -0.923863  -1.109328
#
#                     6          7          8          9  ...         150  \
# idx                                                     ...
# pat_number   6.000000   7.000000   8.000000   9.000000  ...  150.000000
# severity     1.000000   1.000000   1.000000   1.000000  ...    3.000000
# constancy    1.000000   1.000000   1.000000   1.000000  ...    3.000000
# age         66.000000  74.000000  58.000000  74.000000  ...   68.000000
# gender       1.000000   1.000000   1.000000   1.000000  ...    2.000000
# ...               ...        ...        ...        ...  ...         ...
# 283         -1.743754  -1.184359  -1.359995  -1.107242  ...   -1.485589
# 284         -1.743714  -1.217882  -1.360021  -1.116414  ...   -1.486356
# 285         -1.743523  -1.224489  -1.360155  -1.127783  ...   -1.487368
# 286         -1.742894  -1.225101  -1.360293  -1.130476  ...   -1.488168
# 287         -1.744557  -1.225101  -1.360323  -1.117656  ...   -1.488808
#
#                    151         152         153         154         155  \
# idx
# pat_number  151.000000  152.000000  153.000000  154.000000  155.000000
# severity      3.000000    3.000000    3.000000    3.000000    3.000000
# constancy     3.000000    3.000000    3.000000    3.000000    3.000000
# age          49.000000   51.000000   66.000000   45.000000   74.000000
# gender        2.000000    1.000000    1.000000    1.000000    1.000000
# ...                ...         ...         ...         ...         ...
# 283          -1.074087   -1.003103   -0.996204   -1.740179   -1.447827
# 284          -1.074077   -1.002612   -0.994606   -1.740226   -1.445859
# 285          -1.074091   -1.003404   -0.994287   -1.740254   -1.440550
# 286          -1.074112   -1.004197   -0.994368   -1.740259   -1.427560
# 287          -1.074124   -1.002548   -0.993982   -1.740229   -1.401408
#
#                    156         157         158         159
# idx
# pat_number  156.000000  157.000000  158.000000  159.000000
# severity      3.000000    3.000000    3.000000    3.000000
# constancy     3.000000    3.000000    3.000000    3.000000
# age          67.000000   59.000000   34.000000   72.000000
# gender        1.000000    2.000000    1.000000    2.000000
# ...                ...         ...         ...         ...
# 283          -1.043098   -1.684661   -1.077221   -1.393487
# 284          -1.042748   -1.684662   -1.077203   -1.393533
# 285          -1.042608   -1.684662   -1.077191   -1.393537
# 286          -1.042606   -1.684661   -1.077185   -1.393493
# 287          -1.042621   -1.684661   -1.077184   -1.393486
#
# [295 rows x 159 columns]

# %%
idxs = np.random.permutation(range(159))[:]
x = df.iloc[7:, idxs].T.to_numpy()
y = df.iloc[1, idxs].T.to_numpy()

y23 = np.copy(y)
y23[y == 1] = 0
y23[y == 2] = 1
y23[y == 3] = 1
np.unique(y23)
# Out:
# array([0., 1.])

# %%
chain = T0_est(T, x, y23, K, sigma, 5, 500, 1).chain_builder()
# Out:
# Acceptance Rate = 21905.340353873558072883548855216719856734453549125
#
# 1/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22146.486697929528300336737731912132809139769684424
#
# 2/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 22084.37876312315715626429573822339187181955509194
#
# 3/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 0.000045153006478236685733729625466899196971476813879346
#
# 4/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 0.000045153006478236685733729625466899196971476813879346
#
# 5/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 22025.428005710701871847421708972004512664452768146
#
# 6/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 22333.526813038725534575485335469314236517980274057
#
# 7/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 22764.530088053974418284694766985062909931640787804
#
# 8/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 23556.788808814624159035350628090912473414316213334
#
# 9/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.000045281051039585959636124545359894003192477775607526
#
# 10/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 15764.081709728647602139951449549066629677615052193
#
# 11/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 0.000045300530815417258723197040014020393115443308498061
#
# 12/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 21786.210607643495613940875404371549525534989440375
#
# 13/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.000045282619888266878845850361812836335690436545910515
#
# 14/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.9980074811083081855957415185362103797549415172105
#
# 15/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 21799.601758212805471487416887176271819056977212783
#
# 16/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 23070.495455865563413719727904680421012221697185728
#
# 17/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22018.645631385634338001350451162958836602532151952
#
# 18/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.000045290084173416861221149753697295156888668674256428
#
# 19/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.000045273618044027901442533709607903716107103641310921
#
# 20/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21863.076429287004335995547787012194462495666530322
#
# 21/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22545.905028102473668205396483705322867978342618187
#
# 22/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 21302.755452897029622388876529379758720995722694886
#
# 23/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 21220.776625268750739597389257634411275035081611423
#
# 24/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 0.000045575692728078247044066381684866234696511105787617
#
# 25/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 0.00004587191940486159243074351171644163830989343180235
#
# 26/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 22216.290721521486805209454829448426148743487971774
#
# 27/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 22078.83574853844431480592017910922032941023138765
#
# 28/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 22141.18138008928728934610675989763574076283327194
#
# 29/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 21966.992793295337474252184560012151074911322364808
#
# 30/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.000045239958782619656041648051753777800225382303815047
#
# 31/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 20918.96688458200688021451128807658839534019181812
#
# 32/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 21049.72380503931437474111613361404114594620088894
#
# 33/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 20418.949385937568726593854939174257444143789221394
#
# 34/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 1.0003889242155764725613815411306523930583912885019
#
# 35/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 0.00004531305522187927120800191236653267005008162742343
#
# 36/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 1.4770766596171854365376171692303786028987551236588
#
# 37/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 22108.397663225531224630948598155118220463257226868
#
# 38/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 22060.845298269892634378381476139722368261396567195
#
# 39/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22057.149543607600244236670111567079559449926038118
#
# 40/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 10399.408417646451460311951666460904706342735690189
#
# 41/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 21236.035575311820655106726697063533916029786798242
#
# 42/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 22029.255963869197460136794839860717576382863918431
#
# 43/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22084.936161001131304137932675861187338806193077052
#
# 44/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21938.862509299046215201900907461429873681912533204
#
# 45/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 20846.934998818691648270276323345567415830279355757
#
# 46/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 22075.236100710859006772405323141798202646686319753
#
# 47/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 22139.933963553903250937369338936755803916169862145
#
# 48/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 0.000045568989223825231418989933835012900436264645202168
#
# 49/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 22047.852753957802314980852239040770679760744795863
#
# 50/500 in findind T0...
#
# Current Number of Points in T0: 149
# Acceptance Rate = 22006.035669722835069202564471320666682298510751382
#
# 51/500 in findind T0...
#
# Current Number of Points in T0: 150
# Acceptance Rate = 20796.762424292704314001147465566255155956098194083
#
# 52/500 in findind T0...
#
# Current Number of Points in T0: 149
# Acceptance Rate = 6845.3195408830398625550302102326627291094116071645
#
# 53/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 0.000045330162897026344104881081961442741462202744160959
#
# 54/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 30449.429620824215201646994742856678534279683526944
#
# 55/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 20631.234229286182809143970744231084687046917291527
#
# 56/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21702.992890820236517872822823839973963809426421812
#
# 57/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 16883.526062622921843603367619569415906984023418249
#
# 58/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 22560.268036026215329355432041294098678427568751265
#
# 59/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 22012.920614571471383519896342404951854363909709994
#
# 60/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21635.386585050003954817968367406702596304362974817
#
# 61/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 18297.320625160075567866518164290985538441396838356
#
# 62/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 9116.0522552362877771311374556611352190766605932593
#
# 63/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 21870.59748988328770876330739810572077850404938713
#
# 64/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 20564.161093683791153619642926802640392424768827572
#
# 65/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 10789.084711191481102129924911876678195009381804188
#
# 66/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 20364.454736738355256591555993918622297995078762036
#
# 67/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.000045620899138067986649716579526067943670244130722488
#
# 68/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 1.0113221845844166257993512209569757386930033984732
#
# 69/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000044739882259679750320659850514638650896170807550928
#
# 70/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 22020.487489291567651643021068537570931301541106291
#
# 71/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 1.7060855272590229397894889053668262746982124847933
#
# 72/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 1.0014276207453085789191462705170445194097427498959
#
# 73/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 0.99980027001169918242905178047016047978733356657897
#
# 74/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 19101.496974577611136531828240485867152762479784291
#
# 75/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 21486.267813688450220911087302938548214022344644013
#
# 76/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 6726.9310308984549222461198035044923025697618466555
#
# 77/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000045580794838161341741311551243255156955797031054999
#
# 78/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.98311011127014659814102690443366125357057432283024
#
# 79/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 1.0633359627803633289788282775448966908639538898686
#
# 80/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 17932.631477488079692436495520161874009955732043793
#
# 81/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.98677083511286532118209580331997062659415751325406
#
# 82/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000045996533154753124981456477764121599607305625463474
#
# 83/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 13170.547312110435664286605289871746098185728606896
#
# 84/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.000045636649195140058318061997384473495333599973780717
#
# 85/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.000045636649195140058318061997384473495333599973780717
#
# 86/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 16327.819385043331272102113887390628151316534059289
#
# 87/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 18600.384045822045512649797478433511200173869370378
#
# 88/500 in findind T0...
#
# Current Number of Points in T0: 137
# Acceptance Rate = 24207.597654133013628901397578743121579869142103563
#
# 89/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 0.82187631607267639510971828244276515380165739193281
#
# 90/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 22104.92875592842890175472169338174388925012852237
#
# 91/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 22049.815433911722206513402017287333728134341199903
#
# 92/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.48307655185230451823753490118789059481072031771754
#
# 93/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 19400.50873674558492161665483766716586442267264248
#
# 94/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 23076.655589595119765355316233062426137814739312888
#
# 95/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 0.98357191501312505853205213050280065303521733299199
#
# 96/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 0.000045212824847019498488563396422399292295598422246939
#
# 97/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 21991.74247395870150369145493739531103293098041624
#
# 98/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.9659850192990462106945085231754104826493167288775
#
# 99/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.97066698189515189016570694658153426727229628465768
#
# 100/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 21631.929224142547220082693407178957601886078114708
#
# 101/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 21867.552447033524564243122156955122278321076302133
#
# 102/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 1461.2526637820932024343390380583412748265608096919
#
# 103/500 in findind T0...
#
# Current Number of Points in T0: 138
# Acceptance Rate = 1.0983204187350625195822255773558488646138235926111
#
# 104/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.000044455885330918694635568483609781306775107442256961
#
# 105/500 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 1.5051345655920432678256886638759247147629040043043
#
# 106/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000045430213803431240598329541665947636684310019469322
#
# 107/500 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 22482.871343322962968407820075625832862851244820309
#
# 108/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.00004507185628410980472041081148584384135344961683974
#
# 109/500 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 1.7523475818985291935914603276025403297581604891484
#
# 110/500 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 1.2433741879163224600409836327701650918636051138307
#
# 111/500 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 1.1121799842087933848727373942079137225303738888966
#
# 112/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 0.000045351454543118452168347824857826113902845223718069
#
# 113/500 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 22064.28845581515739614477964744832349816542233183
#
# 114/500 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 23710.588954505453156150298585665790509593340359565
#
# 115/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.98368181333461154932523857030324457806468344146922
#
# 116/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 1.042514130135986512022889545221192574508607264329
#
# 117/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 0.000044513595664557137387573446330431103290089943945427
#
# 118/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 0.29343040184161146283597430314356422840227157567078
#
# 119/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 21016.351083278136404541120269961087727086956123815
#
# 120/500 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 22837.422765476676255559911412867482748298951165333
#
# 121/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 22005.357617311270080540561072151477922126580478329
#
# 122/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 21996.697814264831663582574496884024007140993522309
#
# 123/500 in findind T0...
#
# Current Number of Points in T0: 149
# Acceptance Rate = 10228.937991015850185894792651603097708193354148442
#
# 124/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 18549.824515867901714600949539011514233681870261334
#
# 125/500 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 22032.44638988778924145283311935246444963895427377
#
# 126/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 0.92001113993416810783016660109103106579530915762112
#
# 127/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 0.62468506473596852757776820892560050702563076241174
#
# 128/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 0.000045000468862435226990114890761874181451463324166154
#
# 129/500 in findind T0...
#
# Current Number of Points in T0: 148
# Acceptance Rate = 1.0389976400734832308366626751878966711680334261389
#
# 130/500 in findind T0...
#
# Current Number of Points in T0: 149
# Acceptance Rate = 22287.304635690339482344764788628321306821217540259
#
# 131/500 in findind T0...
#
# Current Number of Points in T0: 150
# Acceptance Rate = 22584.154165818470687583703453699212707642045301943
#
# 132/500 in findind T0...
#
# Current Number of Points in T0: 151
# Acceptance Rate = 0.90716427690841260908424544110173864854267612664125
#
# 133/500 in findind T0...
#
# Current Number of Points in T0: 151
# Acceptance Rate = 0.000045067072186844112885732714131432680326079248292038
#
# 134/500 in findind T0...
#
# Current Number of Points in T0: 151
# Acceptance Rate = 2.2156242371372958578443858156927412724191135979359
#
# 135/500 in findind T0...
#
# Current Number of Points in T0: 152
# Acceptance Rate = 0.98838555388623703643801751789177052962198290833583
#
# 136/500 in findind T0...
#
# Current Number of Points in T0: 152
# Acceptance Rate = 22353.480144341726170383313043000180201375995969266
#
# 137/500 in findind T0...
#
# Current Number of Points in T0: 153
# Acceptance Rate = 0.97453666444150832609329597147893087747869156029735
#
# 138/500 in findind T0...
#
# Current Number of Points in T0: 153
# Acceptance Rate = 0.000045270638075595642187009940814704025412194572803276
#
# 139/500 in findind T0...
#
# Current Number of Points in T0: 153
# Acceptance Rate = 22035.679413313752723269770985425368050446199672864
#
# 140/500 in findind T0...
#
# Current Number of Points in T0: 154
# Acceptance Rate = 22159.126231059980557280858688788670362420368656127
#
# 141/500 in findind T0...
#
# Current Number of Points in T0: 155
# Acceptance Rate = 21985.441788288688736087495804233936352531185497258
#
# 142/500 in findind T0...
#
# Current Number of Points in T0: 156
# Acceptance Rate = 22192.627049221075174795163861405238120807580114339
#
# 143/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 1.2253083988898247198660712453499368088524529779372
#
# 144/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 1.0800785738729716866702038053826983315121564871789
#
# 145/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 0.9774014025560860492592311385925254819354209867259
#
# 146/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 13169.897195154528100521760856126567705239970114274
#
# 147/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 2443.8292913471445131445535517068850602613667998751
#
# 148/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 0.000045273378103083489311345955056568055662464011523912
#
# 149/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 1.1324280644676275072251837450401221885434770227717
#
# 150/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 6801.0358814449386737387978317834168228371501310826
#
# 151/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 22421.763031412485566280139009155661003757055979799
#
# 152/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 0.57043212995684995101428337283454179847501591016914
#
# 153/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 9003.9448547207764677499525789748252098408863244025
#
# 154/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 22030.138295679635607415673651989522511917028040133
#
# 155/500 in findind T0...
#
# Current Number of Points in T0: 156
# Acceptance Rate = 23287.376819196556600167742124480277814416403465016
#
# 156/500 in findind T0...
#
# Current Number of Points in T0: 157
# Acceptance Rate = 22208.801268894089593521035289482429843117298455407
#
# 157/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 0.97391857758894140763072075179204779438384126984218
#
# 158/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 0.000045188018759794253514422115859135210320983354326704
#
# 159/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 1.4043117087301937293013717568733179899514802957126
#
# 160/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 11856.032628752477693477138537761523284891357457664
#
# 161/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 1.1505435086563384098801641544479102569843283764659
#
# 162/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 0.000045008289986992487282067427665039723014290595405706
#
# 163/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 22311.601720933414938746237283324339596304543826322
#
# 164/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 0.85015977839090405075539456719973814830141166601266
#
# 165/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 0.53129398620822231759341763667857832558711368998778
#
# 166/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 31104.148951715583040476010652053096808605668230064
#
# 167/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 0.00004553697065343809661144752136219503807185118650384
#
# 168/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 0.000045360077817561044044327628818635946014522968176906
#
# 169/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 0.93683774766340573661660317767323682708095302062843
#
# 170/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 25136.199188080164787852289857714198568279391306905
#
# 171/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 18601.846588566073281640197830152926468145488681749
#
# 172/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 0.000044876396190106202040529063702732723792816421862813
#
# 173/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 1.560759786976944358659337867895426806898822868101
#
# 174/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 5817.6808432219929671124171801098947592717449267198
#
# 175/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 0.99711988968953724201349580980602716701851197559401
#
# 176/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 0.99470374255863526492325215783967783215594640451937
#
# 177/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 0.96704046815734172381748770609715104370657774164435
#
# 178/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 0.86923431158230799197605228778970525051806464700471
#
# 179/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 21768.598698429825260754891650720464482201476721645
#
# 180/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 0.00004549218369974377661070602123241563086505148915536
#
# 181/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 0.72269199541079932726787031074915174386678736808941
#
# 182/500 in findind T0...
#
# Current Number of Points in T0: 158
# Acceptance Rate = 2.4098003007097696074448239290979294802843124956985
#
# 183/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 0.98348913542452504050050679761186610978829132723987
#
# 184/500 in findind T0...
#
# Current Number of Points in T0: 159
# Acceptance Rate = 1.0235067746939544550374606258033808108549158960787
#
# 185/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 0.87750708830932754650997929230803519740391321629672
#
# 186/500 in findind T0...
#
# Current Number of Points in T0: 160
# Acceptance Rate = 1.0505785322032499664388943450564131353293760251047
#
# 187/500 in findind T0...
#
# Current Number of Points in T0: 161
# Acceptance Rate = 1.0309557957106356828790932982340097995828210206002
#
# 188/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 21826.516779817724336825408841833974516780890479193
#
# 189/500 in findind T0...
#
# Current Number of Points in T0: 163
# Acceptance Rate = 1.0296894760642969678592304693154867061713843426666
#
# 190/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 0.000045489717225293962716564488722832858317651837545084
#
# 191/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 0.96958588374034787947697925763379852872249027629554
#
# 192/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 0.5687363828928673357503502224315895133011837962381
#
# 193/500 in findind T0...
#
# Current Number of Points in T0: 162
# Acceptance Rate = 1.0017483517776068354382873499772813790464364383884
#
# 194/500 in findind T0...
#
# Current Number of Points in T0: 163
# Acceptance Rate = 23005.200258469412211048723600571580021817708363614
#
# 195/500 in findind T0...
#
# Current Number of Points in T0: 164
# Acceptance Rate = 1.6918854041702718124651292428226793261907922552366
#
# 196/500 in findind T0...
#
# Current Number of Points in T0: 165
# Acceptance Rate = 0.000045338473651042779935188136780115559650907857724512
#
# 197/500 in findind T0...
#
# Current Number of Points in T0: 165
# Acceptance Rate = 1.5874057653546095675763376802465009747625089460366
#
# 198/500 in findind T0...
#
# Current Number of Points in T0: 166
# Acceptance Rate = 0.00004551947448376095744038646063776127432159991768025
#
# 199/500 in findind T0...
#
# Current Number of Points in T0: 166
# Acceptance Rate = 0.000044827425789297705779373915059536390147919093298918
#
# 200/500 in findind T0...
#
# Current Number of Points in T0: 166
# Acceptance Rate = 0.000044827425789297705779373915059536390147919093298918
#
# 201/500 in findind T0...
#
# Current Number of Points in T0: 166
# Acceptance Rate = 0.00004518846720811395882074032431297124948390481620473
#
# 202/500 in findind T0...
#
# Current Number of Points in T0: 166
# Acceptance Rate = 22288.180734987786977436247410886165596403639852034
#
# 203/500 in findind T0...
#
# Current Number of Points in T0: 167
# Acceptance Rate = 0.97560762033742277341330667319044833711618079224585
#
# 204/500 in findind T0...
#
# Current Number of Points in T0: 167
# Acceptance Rate = 0.00004518846782640852891387969394645517885577050273213
#
# 205/500 in findind T0...
#
# Current Number of Points in T0: 167
# Acceptance Rate = 1.7754913946499526794799858716627031581224325095313
#
# 206/500 in findind T0...
#
# Current Number of Points in T0: 168
# Acceptance Rate = 0.00004497496431267939550800984999466456342085684978236
#
# 207/500 in findind T0...
#
# Current Number of Points in T0: 168
# Acceptance Rate = 0.000045276052839935327724556303147186057826558037801761
#
# 208/500 in findind T0...
#
# Current Number of Points in T0: 168
# Acceptance Rate = 0.95837804201331083483029894926487257054392075755667
#
# 209/500 in findind T0...
#
# Current Number of Points in T0: 168
# Acceptance Rate = 22096.657721510557047851549054132143582332874650304
#
# 210/500 in findind T0...
#
# Current Number of Points in T0: 169
# Acceptance Rate = 0.81673990037789730017098936028631166883996484820041
#
# 211/500 in findind T0...
#
# Current Number of Points in T0: 169
# Acceptance Rate = 0.95957973060820201298508478406514204360605250775007
#
# 212/500 in findind T0...
#
# Current Number of Points in T0: 169
# Acceptance Rate = 1.0254616635456884602313850171301022966867159373872
#
# 213/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.000045522057163595001865055699488671342076955880815358
#
# 214/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 1.0430486564310088282063966725548429656287449641634
#
# 215/500 in findind T0...
#
# Current Number of Points in T0: 171
# Acceptance Rate = 0.000044890928163619343042002416997387945466247261795266
#
# 216/500 in findind T0...
#
# Current Number of Points in T0: 171
# Acceptance Rate = 0.99202170083665762443309758464956244059609094845809
#
# 217/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.95837864181108722932928118264678064078364162572347
#
# 218/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.87749318210790403035310335592026721207738086685605
#
# 219/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 5446.0305755464907258487708876045520089719542936317
#
# 220/500 in findind T0...
#
# Current Number of Points in T0: 169
# Acceptance Rate = 0.000036023036457847256416383845275210287242248812830353
#
# 221/500 in findind T0...
#
# Current Number of Points in T0: 169
# Acceptance Rate = 22043.384130605855634055188369877795961425378735915
#
# 222/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.000045330243724754772904549823272196707090859638181618
#
# 223/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.56429837997642562636979332455534833386168378223282
#
# 224/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 0.000045262977000056124170955707743626624592276774849629
#
# 225/500 in findind T0...
#
# Current Number of Points in T0: 170
# Acceptance Rate = 1.0452459635378557846831960537390703505731404149669
#
# 226/500 in findind T0...
#
# Current Number of Points in T0: 171
# Acceptance Rate = 1.0893824368524140801242475238522150459967061561877
#
# 227/500 in findind T0...
#
# Current Number of Points in T0: 172
# Acceptance Rate = 0.000045366736684069421566646353836063668789502966102451
#
# 228/500 in findind T0...
#
# Current Number of Points in T0: 172
# Acceptance Rate = 22209.588212260827069077094572733912855571916979777
#
# 229/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 0.000044512004308495983906415655958726965513588315091362
#
# 230/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 1.1394542645586335726048021740130042942736479382423
#
# 231/500 in findind T0...
#
# Current Number of Points in T0: 172
# Acceptance Rate = 22281.98074636969928624980072158246526626906995117
#
# 232/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 1.1450393132615308238657662252598077086527720243404
#
# 233/500 in findind T0...
#
# Current Number of Points in T0: 172
# Acceptance Rate = 1.0248730520247979084701836856059893838554738241113
#
# 234/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 0.000045106214384024674973463813789147029749691055155267
#
# 235/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 1.1395835145784850025233502439613477358829125006119
#
# 236/500 in findind T0...
#
# Current Number of Points in T0: 172
# Acceptance Rate = 1.7241091859425664571864373622850293668695773181086
#
# 237/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 0.000046114738542401361619090542240541221632104705498587
#
# 238/500 in findind T0...
#
# Current Number of Points in T0: 173
# Acceptance Rate = 1.7183004187680059897604020171320912275698331411348
#
# 239/500 in findind T0...
#
# Current Number of Points in T0: 174
# Acceptance Rate = 0.49395142164574548909009113211103855957201753099178
#
# 240/500 in findind T0...
#
# Current Number of Points in T0: 174
# Acceptance Rate = 0.000045316529269334474845963932183844407145320852721833
#
# 241/500 in findind T0...
#
# Current Number of Points in T0: 174
# Acceptance Rate = 22067.024276376650813748113664262935238840169275359
#
# 242/500 in findind T0...
#
# Current Number of Points in T0: 175
# Acceptance Rate = 1.0149062503920542117036933235564595406667741638434
#
# 243/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.000045103414768756818563798260012316528704093658228817
#
# 244/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 1.2037600887744906238619847985946466257660265749263
#
# 245/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 1.0286991730667879537260650531636413568621682256627
#
# 246/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.00004530294958097780826169772377783713613422570905726
#
# 247/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 1.7725425840004698852413136622396227626117001241526
#
# 248/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 1.7475799347819608920149576237855232428334854660506
#
# 249/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.9651189943245140539602596163957205122522931243307
#
# 250/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.99795348708256266330783067362941822264395867667063
#
# 251/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.99080849846401809987665451147441535826771258082473
#
# 252/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.57206695463169125630564637860095211353883574470288
#
# 253/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 22123.329460505610533115341306236626096381021144353
#
# 254/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.98209039260899435422146554176761000635480593358893
#
# 255/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.58391692061238374774613870787512688650492722908568
#
# 256/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 13806.598667982208590838770917803329778969233725909
#
# 257/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.97374934754397664822562346494142448377379486452096
#
# 258/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.54771492522245170991235993067496837054037239418198
#
# 259/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 0.000045153128465828766460063408931942507963913067783095
#
# 260/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 1.0045475211506628302679507126462396688020607707727
#
# 261/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.99928081249590620202709053962249295274876837392393
#
# 262/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 1.0468976060231526667310986222978891954270091099447
#
# 263/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.90160059753874271838131289907128071649221099208887
#
# 264/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.83857748445934989691051862426182065400663323937631
#
# 265/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 1.0078826817924431350415528041049505353809039083536
#
# 266/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.000045230706418731515525557743795658914204525382330532
#
# 267/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.87184188645246724209721498902291103946569219197096
#
# 268/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.94622927021124672280535673537895864635832751966093
#
# 269/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 1.0083473888348688695186179913290628869927369132814
#
# 270/500 in findind T0...
#
# Current Number of Points in T0: 179
# Acceptance Rate = 1.3744286082313652109670390573964127339390180283516
#
# 271/500 in findind T0...
#
# Current Number of Points in T0: 180
# Acceptance Rate = 1.0009289654352469184657399911324543403286096859477
#
# 272/500 in findind T0...
#
# Current Number of Points in T0: 179
# Acceptance Rate = 1.018938780388773434166764967609458908908326030466
#
# 273/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 22175.03921883877561548123157676500022136222021281
#
# 274/500 in findind T0...
#
# Current Number of Points in T0: 179
# Acceptance Rate = 11889.257596475104846444981605709570247042604837292
#
# 275/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 0.000044392533897168132544247450475058977000492049724992
#
# 276/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 1.0010800638921316758619335631927602946015283439812
#
# 277/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 12112.238245751605275070135945214802445471584274759
#
# 278/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 1.1571268566334469883907016916393434036561280001581
#
# 279/500 in findind T0...
#
# Current Number of Points in T0: 175
# Acceptance Rate = 22058.838236002281722309357513780492079585142128759
#
# 280/500 in findind T0...
#
# Current Number of Points in T0: 176
# Acceptance Rate = 1.6713525981951424937307024353600240140269237829678
#
# 281/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 1.0438572556333888099711217593339711013283328220859
#
# 282/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 1.0179306854362952165440090264359826875012327556578
#
# 283/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.84169674872079100485067468807390504305696692062284
#
# 284/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.000045360051403188340888461334275025458558616969344035
#
# 285/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 0.000046032895864529361948316906606276460970325206105476
#
# 286/500 in findind T0...
#
# Current Number of Points in T0: 177
# Acceptance Rate = 1.0507534181896105914562000319416783682905609581682
#
# 287/500 in findind T0...
#
# Current Number of Points in T0: 178
# Acceptance Rate = 1.0053931977602283366907130843456328187152484210009
#
# 288/500 in findind T0...
#
# Current Number of Points in T0: 179
# Acceptance Rate = 22462.668554183069420930438776351705775112087365985
#
# 289/500 in findind T0...
#
# Current Number of Points in T0: 180
# Acceptance Rate = 2.0179792263227685595006978449255135544112856294843
#
# 290/500 in findind T0...
#
# Current Number of Points in T0: 181
# Acceptance Rate = 0.81303422120416735535279315479851481745088761323051
#
# 291/500 in findind T0...
#
# Current Number of Points in T0: 181
# Acceptance Rate = 0.000043907401919354436599174529692124466431260362689247
#
# 292/500 in findind T0...
#
# Current Number of Points in T0: 181
# Acceptance Rate = 0.53290030241013488785743650207261191133307121856066
#
# 293/500 in findind T0...
#
# Current Number of Points in T0: 181
# Acceptance Rate = 1.546491017725280482690127660497882619819377609539
#
# 294/500 in findind T0...
#
# Current Number of Points in T0: 182
# Acceptance Rate = 1.01255279326180958624687272284711958016704266444
#
# 295/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.49667276764424642360133733100656907520592065160035
#
# 296/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.98573210669179547712067531109980615802368988075838
#
# 297/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.95292703034947542945794147246248481901528333166067
#
# 298/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 1.0010066870285729574647655113532962540933827707344
#
# 299/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 1.5405946740045552680685840491240439744596174285856
#
# 300/500 in findind T0...
#
# Current Number of Points in T0: 185
# Acceptance Rate = 0.99914367581637617269409669993320397914710336764382
#
# 301/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.98553387568690910792122625925453390504171784275097
#
# 302/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.99853678829197831966705508048961517592534302561568
#
# 303/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.85452735929640916595726783551134845701504864154995
#
# 304/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.95383362273331480516116371657397539660332020208932
#
# 305/500 in findind T0...
#
# Current Number of Points in T0: 183
# Acceptance Rate = 0.99892411508655853894944327958386434306132788009826
#
# 306/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.9755124290207481546075073920324014829551792573949
#
# 307/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.85937262916649775669046227252915827143567642529646
#
# 308/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.41559914438735431744209425318226772655644788449035
#
# 309/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 0.000045057489772920221948360610718922844471359502803954
#
# 310/500 in findind T0...
#
# Current Number of Points in T0: 184
# Acceptance Rate = 22103.902880468817587372154149297172352767619683446
#
# 311/500 in findind T0...
#
# Current Number of Points in T0: 185
# Acceptance Rate = 1.1035529415509075206319496993696502232780809133743
#
# 312/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 1.0257951584832650231881025798576896378545067647435
#
# 313/500 in findind T0...
#
# Current Number of Points in T0: 187
# Acceptance Rate = 1.2778346825318165088138481505323340416799314689837
#
# 314/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 0.92943018227677436364723675212254779681778508772554
#
# 315/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 0.79344566110663991656579702568513682984073474094938
#
# 316/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 0.9525871316667722208706973363904224113045260318938
#
# 317/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 0.82351084908766261962056720384103336933198559242869
#
# 318/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 0.33778606885685779828186120460308637597113052840553
#
# 319/500 in findind T0...
#
# Current Number of Points in T0: 186
# Acceptance Rate = 1.2868166367826646828262905899712999476984864051315
#
# 320/500 in findind T0...
#
# Current Number of Points in T0: 187
# Acceptance Rate = 0.98779272674344922854798473725645977178426078498909
#
# 321/500 in findind T0...
#
# Current Number of Points in T0: 187
# Acceptance Rate = 1.6296743934512180370313945727459875856024388882774
#
# 322/500 in findind T0...
#
# Current Number of Points in T0: 188
# Acceptance Rate = 0.00004512415965237878585327422199216049131392409132527
#
# 323/500 in findind T0...
#
# Current Number of Points in T0: 188
# Acceptance Rate = 0.97609299256108311848433078414308710026435454809625
#
# 324/500 in findind T0...
#
# Current Number of Points in T0: 188
# Acceptance Rate = 0.98778940674802217467040478394718799679480938252097
#
# 325/500 in findind T0...
#
# Current Number of Points in T0: 188
# Acceptance Rate = 0.98778940674802217467040478394718799679480938252097
#
# 326/500 in findind T0...
#
# Current Number of Points in T0: 188
# Acceptance Rate = 1.0021516559456522086985069585489016735874649068178
#
# 327/500 in findind T0...
#
# Current Number of Points in T0: 189
# Acceptance Rate = 0.00004524091588394607976556159952123102473214145757014
#
# 328/500 in findind T0...
#
# Current Number of Points in T0: 189
# Acceptance Rate = 1.4454594655698596614609646667157315836285442542923
#
# 329/500 in findind T0...
#
# Current Number of Points in T0: 190
# Acceptance Rate = 0.000044977384468321362848283167187493465030917064752254
#
# 330/500 in findind T0...
#
# Current Number of Points in T0: 190
# Acceptance Rate = 0.81925007150573192753073192344127354417551403993703
#
# 331/500 in findind T0...
#
# Current Number of Points in T0: 190
# Acceptance Rate = 1.0000647738114588644554736590259810903313605612638
#
# 332/500 in findind T0...
#
# Current Number of Points in T0: 191
# Acceptance Rate = 0.000045084002496954173809672324142224963327912502559174
#
# 333/500 in findind T0...
#
# Current Number of Points in T0: 191
# Acceptance Rate = 22160.528977345047833771365718363951738683553392572
#
# 334/500 in findind T0...
#
# Current Number of Points in T0: 192
# Acceptance Rate = 22158.99649006038720233229280824147872598321050128
#
# 335/500 in findind T0...
#
# Current Number of Points in T0: 193
# Acceptance Rate = 1.1988235867891187744661271285941044718582883600421
#
# 336/500 in findind T0...
#
# Current Number of Points in T0: 194
# Acceptance Rate = 0.97932047067562836924648613859684571102008617085725
#
# 337/500 in findind T0...
#
# Current Number of Points in T0: 194
# Acceptance Rate = 2.209754424167342296389669117247129477893089298548
#
# 338/500 in findind T0...
#
# Current Number of Points in T0: 195
# Acceptance Rate = 22056.543509206250705511273580645364629040955653124
#
# 339/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 1.0937248398045850474324970190241966171052085036091
#
# 340/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.45506208216950766661963101112957477723395268380547
#
# 341/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.87469142089176540229221515841598727822739996730531
#
# 342/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.8330179792653753816422387673503229413338870399079
#
# 343/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.98772001560277834561152489022193619469109347137271
#
# 344/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.000045492388653726810013154727199296364123225680043505
#
# 345/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.000045216324845989508655904951296865433613404952666813
#
# 346/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 0.37708378122467174944889656100892422764526835101971
#
# 347/500 in findind T0...
#
# Current Number of Points in T0: 197
# Acceptance Rate = 1.0320007872293264149355341229328296542610368246717
#
# 348/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.97946598336844915153053705438984218514620324917834
#
# 349/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.61402476691023000856232817739866743125725145650961
#
# 350/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.71962942941947221978027604356840175120748197405033
#
# 351/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.98704739573711471127379491149202705402856067087958
#
# 352/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.000045020449050282169926823496520877505449383033678265
#
# 353/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.3917814817775154152430272929856981828431345387745
#
# 354/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.79493354869181618875756794125534257610232617959266
#
# 355/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 0.61218546359907683049991265124943530193739052732733
#
# 356/500 in findind T0...
#
# Current Number of Points in T0: 196
# Acceptance Rate = 1.0390369656886589251856190024722821778771840887097
#
# 357/500 in findind T0...
#
# Current Number of Points in T0: 195
# Acceptance Rate = 0.65069908257268421205486094910398675800996312830173
#
# 358/500 in findind T0...
#
# Current Number of Points in T0: 195
# Acceptance Rate = 0.91417949994008667431838534224031103749339925237109
#
# ...
#
# 382/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.61156244994172258396558533179377552599141820378434
#
# 383/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.37840300838590968238997548668895713573046799503466
#
# 384/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 1.2739537760334453102514860894415986267901927480663
#
# 385/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.78986369349415958241468006284141406481384456196203
#
# 386/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.94225460776308553706785728219354261934209619061481
#
# 387/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.9599019433601115554152765492120059160925717209108
#
# 388/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.64223534492162745996934182493783088033605076372662
#
# 389/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.99124526391791044840748397659695501348028358745029
#
# 390/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.77187599110695189409949361888124019645744203275181
#
# 391/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.75825338582599721898691080357576699779458157715511
#
# 392/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.75825338582599721898691080357576699779458157715511
#
# 393/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 0.000043153541771291666013727035661628156612196042791176
#
# 394/500 in findind T0...
#
# Current Number of Points in T0: 201
# Acceptance Rate = 22107.291233632974651238354880546446695370486669491
#
# 395/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 0.96051986826591042541779237009868883640117851784522
#
# 396/500 in findind T0...
#
# Current Number of Points in T0: 202
# Acceptance Rate = 1.0098764098903434017617050286230320838638325297918
#
# 397/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 1.0222739830076301305101346815604056501260274699461
#
# 398/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.95975899587346438840817224057271081337600404213133
#
# 399/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.9905386303826265013544312344850082421166977199235
#
# 400/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.9382810608106977931925420841835535803182047817223
#
# 401/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.90752186292058801595370679884761113658917155581411
#
# 402/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 2.061591312917699567799315382630561188121771721009
#
# 403/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.8181123556721371920064519860923218043267290519024
#
# 404/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.89349523325973506042451745240261636431464378444654
#
# 405/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.99195144423797070437178163317048243279809151120536
#
# 406/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.77170446799447487788165023052468428670225192945066
#
# 407/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.00004514284522097180910243427818720620672827363561159
#
# 408/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.000044969742687699233898185860251119422290002374147644
#
# 409/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.8387008861930706912418136316846001775485213183905
#
# 410/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.78357727861767938002444307469418516328044236681693
#
# 411/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.81811529443918794718555222155368958784760465590413
#
# 412/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.9525266951037603704913820054056938264047464636566
#
# 413/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 23060.627153543887545395628415091408241619257862814
#
# 414/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 1.0988573404359503138527473742602534284632672267121
#
# 415/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.46354391386302828585023591035914753121622003038025
#
# 416/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 1.4879688921808233888520701707350561138516067277311
#
# 417/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 1.6546740791955527321446913322860730564217382882913
#
# 418/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.000045061567774730384083311597888325386547348718213347
#
# 419/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 1.4050987944008113943865344623557755111526705615171
#
# 420/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.58475758275987403884389396701208058677578116716308
#
# 421/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 1.0092204074655231342489627781411471846785033018082
#
# 422/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.000045320730428599455396744258895571285025739079202333
#
# 423/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.000045718499208767465913591375314197895698062741617746
#
# 424/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.70954315481046253928878377422380364951363883521642
#
# 425/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.82687061039955880010266288786175773065519045442722
#
# 426/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.000045718499208767465913591375314197895698062741617746
#
# 427/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 0.9768395913201813703295700303320251842903531859855
#
# 428/500 in findind T0...
#
# Current Number of Points in T0: 203
# Acceptance Rate = 1.006081571738846933446612208425325587017310541318
#
# 429/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.000043169970216299219773530693971459165811848580987395
#
# 430/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 0.81611440345466084171201943609887388242354399687363
#
# 431/500 in findind T0...
#
# Current Number of Points in T0: 204
# Acceptance Rate = 1.0156767942304550163882575054340621880111238927244
#
# 432/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 0.92838413289877808579701369326654965385270932833125
#
# 433/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 0.00004514643573291442186436228547170658896671123186346
#
# 434/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 0.80034401758245634514526115512434001010808383849882
#
# 435/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 1.1345505510819435143757201451413413984192359755187
#
# 436/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.94828840593900903478914871000724120664114848560949
#
# 437/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.95160124510207087756868455126844053072206855259418
#
# 438/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.99358824305693782794313267952761410502700506053118
#
# 439/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 1.0207207207239767820352575607736551105936713763929
#
# 440/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.000045156536460908787981841102764123313649269884654356
#
# 441/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.87260953255573447783067311952224268426425292744056
#
# 442/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.000044891799222520564907932350524792986144182357974909
#
# 443/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.9439395363180382112992676712633049398257074121088
#
# 444/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.77942989752772708410918920426392797723514744179757
#
# 445/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.98797947452551850699074127120379517997340811067936
#
# 446/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 0.000045202490507425784127398931208173808537347254286854
#
# 447/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 0.97962210507724707309540261370344022875898416339405
#
# 448/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 22078.036482710596315395751215162766826140485158461
#
# 449/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 1.5352397675357285864253492877027022481219829583599
#
# 450/500 in findind T0...
#
# Current Number of Points in T0: 205
# Acceptance Rate = 1.1148379619286889753490477115085241268795598290272
#
# 451/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.000044596000812621755712731087171455930514997748895665
#
# 452/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 0.73629863104637309876583641166240072977031973811916
#
# 453/500 in findind T0...
#
# Current Number of Points in T0: 206
# Acceptance Rate = 1.0987620360968099012207277513504620347248756824443
#
# 454/500 in findind T0...
#
# Current Number of Points in T0: 207
# Acceptance Rate = 0.95087286322299408054805583616660684099970983500044
#
# 455/500 in findind T0...
#
# Current Number of Points in T0: 207
# Acceptance Rate = 0.76597499880990371298262778682478476277762353119329
#
# 456/500 in findind T0...
#
# Current Number of Points in T0: 207
# Acceptance Rate = 0.000045254991360154413891372657201633527633242376615287
#
# 457/500 in findind T0...
#
# Current Number of Points in T0: 207
# Acceptance Rate = 1.0126131431135965492574653141115336104881396000911
#
# 458/500 in findind T0...
#
# Current Number of Points in T0: 208
# Acceptance Rate = 1.9719990337916900950230891949646330524443060992734
#
# 459/500 in findind T0...
#
# Current Number of Points in T0: 209
# Acceptance Rate = 0.49596483980094868517960552914813251596850876773397
#
# 460/500 in findind T0...
#
# Current Number of Points in T0: 209
# Acceptance Rate = 0.95378429503172423316838708152196980171459662513817
#
# 461/500 in findind T0...
#
# Current Number of Points in T0: 209
# Acceptance Rate = 1.0141619372887303201267515020884619017983071212846
#
# 462/500 in findind T0...
#
# Current Number of Points in T0: 210
# Acceptance Rate = 0.77244314559843201667212938744520347472267513971746
#
# 463/500 in findind T0...
#
# Current Number of Points in T0: 210
# Acceptance Rate = 0.83997981477282365068032285765049020097773403559956
#
# 464/500 in findind T0...
#
# Current Number of Points in T0: 210
# Acceptance Rate = 0.77070450276282571395764465088866703893762872167158
#
# 465/500 in findind T0...
#
# Current Number of Points in T0: 210
# Acceptance Rate = 1.0103790386993715992344881045327977436258605636069
#
# 466/500 in findind T0...
#
# Current Number of Points in T0: 211
# Acceptance Rate = 0.000045057787291782477698724196569256131202113950953784
#
# 467/500 in findind T0...
#
# Current Number of Points in T0: 211
# Acceptance Rate = 1.0234023546367932416016348046782934938203839701724
#
# 468/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 1.0540550561406346120038934874736803863439182544072
#
# 469/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.98768983259426210367034706532790025043864454183501
#
# 470/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 0.000045072272833065454442115980722045006563624289430167
#
# 471/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 0.000043085616377442764487089346446485677982979573260309
#
# 472/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 0.000045376322071394848362631119307782534685073402446921
#
# 473/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 0.93670431309387156212637004062345801624442013546612
#
# 474/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 0.8383810827109812986117417905566638888730906162155
#
# 475/500 in findind T0...
#
# Current Number of Points in T0: 212
# Acceptance Rate = 1.1107323063294184415377984351376702152492461055333
#
# 476/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.000045219998435967343503851922741936984040829177375055
#
# 477/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.72713855687635780184695553529509448971305566502051
#
# 478/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.000045370556611362197033694099701526448216501561943248
#
# 479/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.99779105423191151311959048565538627245820500267043
#
# 480/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.61164692499616658049160711284949931510056383319661
#
# 481/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.99808547203557489504543796985250061747092351120194
#
# 482/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 0.97764313406110630831504357030127850979187041927736
#
# 483/500 in findind T0...
#
# Current Number of Points in T0: 213
# Acceptance Rate = 1.0112705398344325923058488813759264454003461648858
#
# 484/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.75150450287178005799165241745434376804117029993732
#
# 485/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.90210566406627146748510516630137041577200244409894
#
# 486/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.000044974428471402845738154072855704349565968089653157
#
# 487/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.72746899284146418030051703381215405941624222815752
#
# 488/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.97155277910547882635443651980490928521483744328223
#
# 489/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.65861726582762037452153289051571627349148043520593
#
# 490/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.84392512682604499993076638659123098580050230694642
#
# 491/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 0.84118347716735667994319654325281918529587215776015
#
# 492/500 in findind T0...
#
# Current Number of Points in T0: 214
# Acceptance Rate = 1.0423166411123294614909052644558633326856163566215
#
# 493/500 in findind T0...
#
# Current Number of Points in T0: 215
# Acceptance Rate = 0.000044975072472354111376423635562883889724520243015292
#
# 494/500 in findind T0...
#
# Current Number of Points in T0: 215
# Acceptance Rate = 0.00004743829839137313445887712216000832876224534277514
#
# 495/500 in findind T0...
#
# Current Number of Points in T0: 215
# Acceptance Rate = 0.000045226691139801682654714229652158817337667362598903
#
# 496/500 in findind T0...
#
# Current Number of Points in T0: 215
# Acceptance Rate = 0.45535301574147647044473689608843505046477859419073
#
# 497/500 in findind T0...
#
# Current Number of Points in T0: 215
# Acceptance Rate = 0.98965810900574327260782236266639037217559640168815
#
# 498/500 in findind T0...
#
# Current Number of Points in T0: 216
# Acceptance Rate = 1.0481530001370056330199078941177539522693384402038
#
# 499/500 in findind T0...
#
# Current Number of Points in T0: 217
# Acceptance Rate = 0.00004542846220792371677827517858027953938500144347094
#
# 500/500 in findind T0...
#
# Current Number of Points in T0: 217

# %%
T0_hat, counts = stats.mode(chain[1:], axis=0)

# %%
result_df = pd.DataFrame({
    'T0_hat':T0_hat.flatten(),
    'counts':counts.flatten()
})

# Save the DataFrame to a CSV file
result_df.to_csv('/kaggle/working/outputT0.csv', index=False)

# %%
#T0_hat

# %%
fitted = posterior(T,T0_hat[0],x,y23,K,sigma).fitted_values()
logit_fitted = scipy.special.expit(fitted)

labels = np.zeros(len(logit_fitted))
ones= np.where(logit_fitted > 0.5)
labels[ones] = np.ones(len(ones))
acc=sum(labels==y23)/len(labels)

# %%
acc=pd.DataFrame({
    'acc':acc.flatten()
})
acc.to_csv('/kaggle/working/output_acc.csv', index=False)

# %%
print('Accuracy: '+str(sum(labels==y23)/len(labels)))
# Out:
# Accuracy: 0.6226415094339622

# %%
m,cov = posterior(T,T0_hat[0],x,y23,K,sigma).posterior_mean_cov()

# %%
# Save the DataFrame to a CSV file
result_dfm = pd.DataFrame({
    'm':m.flatten()
})
result_dfm.to_csv('/kaggle/working/output_m.csv', index=False)
result_dfc = pd.DataFrame({
    'cov':cov.flatten()
})
result_dfc.to_csv('/kaggle/working/output_cov.csv', index=False)

# %%
#plots
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, -0.2, 0.2, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,m,label='Posterior Mean',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, 50, 100, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,np.diag(cov),label='Posterior Covariance Diagonal',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, -2, 5, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,x[0,:],label='Observation 0',linewidth=1.3)
plt.plot(T,x[1,:],label='Observation 1',linewidth=1.3)
plt.plot(T,x[2,:],label='Observation 2',linewidth=1.3)
plt.plot(T,x[3,:],label='Observation 3',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()
