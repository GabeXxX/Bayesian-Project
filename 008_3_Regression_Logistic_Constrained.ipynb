# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import time
from itertools import product, groupby
import math
import scipy.stats as stats

# %%
from mpmath import mp
mp.dps = 50

# %%
def prior_kernel(s,t):
    return np.exp(-(t-s)**2)+0.0001*(s==t)

def runs(a_list):
    runs_zeros = len([k for k, g in groupby(a_list) if k == 0])
    runs_ones = len([k for k, g in groupby(a_list) if k == 1])
    return runs_ones + runs_zeros

def tr(actions):
    if len(actions)<100:
        return 1
    else:
        return 1-0.02*(100-sum(actions[-100:-1]))/100

# %%
class posterior:
    def __init__(self, T, T0, x, y, K,sigma):
        self.T = T
        self.x = x
        self.y = y
        self.n = y.shape[0]
        self.g = T.shape[0]
        self.T0 = np.array(T0)
        self.sigma = sigma
        self.K = K
        self.K0 = self.get_K0()

    def get_K(self):
        return self.K

    def getter(self):
        return self.K0

    def get_K0(self):
        tau = np.where(self.T0==1)[0]
        K_tau=self.K[:, tau]
        K_tau_tau = self.K[tau[:, None], tau]
        return self.K- np.dot(np.dot(K_tau, np.linalg.inv(K_tau_tau)), K_tau.T)

    def Lx0(self,t):
        L = np.zeros(self.n)
        for i in np.arange(0,self.n):
            L[i] = np.trapz(self.K0[t, :] * self.x[i,:], self.T)
        return L

    def likelihood(self): #p(Y|T0)
        m_matrix = self.M()
        first = np.linalg.det(m_matrix) ** (-0.5)


        inv = np.linalg.inv(m_matrix)
        s11 = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),np.ones(self.n))

        syy = np.dot(np.dot(np.transpose(self.y),inv),self.y)
        s1y = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),self.y)
        b = 0.5*(syy-s1y**2/s11)

        return first/np.sqrt(s11)*(b**(-0.5*(self.n-1)))

    def R0(self,i, j):
        Ri = np.trapz(self.K0[:, :] * self.x[i, :], self.T, axis=1)
        Rij = np.trapz(Ri * self.x[j, :],self.T)
        return Rij

    def M(self):
        return np.array([[self.R0(i, j) for j in range(self.n)] for i in range(self.n)])+np.identity(self.n)

    def posterior_mean_cov(self):
        M_mat = self.M()
        inv = np.linalg.inv(M_mat)
        S11 = np.dot(np.dot(np.transpose(np.ones(M_mat.shape[0])),inv),np.ones(M_mat.shape[0]))
        SY1 = np.dot(np.dot(np.transpose(self.y),inv),np.ones(M_mat.shape[0]))

        def m(t):
            mean = np.dot(np.dot(np.transpose(self.Lx0(t)), inv), (self.y - (SY1 / S11) * np.ones(len(self.y))))
            return mean
        def Kstar(s,t):
            cov = (self.sigma**2)*(self.K0[s,t] - np.dot(np.dot(np.transpose(self.Lx0(s)),inv),self.Lx0(t)))
            return cov

        m = np.fromfunction(np.vectorize(lambda t: m(t)), (self.g,), dtype=int)
        C = np.fromfunction(np.vectorize(lambda t, s: Kstar(s,t)), (self.g,self.g), dtype=int)
        return m,C

    def only_mean(self):
        inv = np.linalg.inv(self.M())
        def m(t):
            mean = np.dot(np.dot(np.transpose(self.Lx0(t)),inv),self.y)
            return mean
        m = np.fromfunction(np.vectorize(lambda t: m(t)), (self.g,), dtype=int)
        return m

    def fitted_values(self):
        m = self.only_mean()
        return np.fromfunction(np.vectorize(lambda i: np.trapz(self.x[i,:]*m,self.T)), (self.n,), dtype=int)

# %%
class T0_est:
    def __init__(self, T, x, y,K,sigma,alpha,n_sim=1000,burn=0):
        self.T= T
        self.x=x
        self.y=y
        self.sigma=sigma
        self.alpha=alpha
        self.n_sim=n_sim
        self.burn=burn
        self.n = y.shape[0]
        self.g = T.shape[0]
        self.K=K
        self.count = 0

        self.T0_init = np.array([0, 1] * (self.g // 2))
        self.action = []

    def chain_builder(self):
        chain = [self.T0_init]
        for i in range(self.n_sim):
            curr=chain[-1]
            chain.append(self.next_T0(curr))
            print('Current Number of Points in T0: '+str(sum(chain[-1])))
        return chain[self.burn:]


    def next_T0(self,current):
        new = self.candidate(current)
        rate=self.acceptance_rate(current,new)
        print('Acceptance Rate = '+str(rate)+'\n')
        treshold = tr(self.action)

        self.count = self.count + 1
        print(str(self.count)+'/'+str(self.n_sim) + ' in findind T0...\n')
        if rate>=treshold:
            self.action.append(1)
            return new

        else:
            self.action.append(0)
            return current

    def candidate(self,old):
        new=old.copy()
        coin = np.random.uniform(0,1,1)

        if coin<0.2: #split
            choices = [i for i in range(1,len(old) - 1) if old[i-1] == 1 and old[i] == 1 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                splitting_point = choice
                new[splitting_point]=0

        if (coin>=0.2) and (coin<0.4): #right removal
            choices = [i for i in range(0,len(old)-1) if old[i] == 1 and old[i + 1] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0

        if (coin>=0.4) and (coin<0.6): #left removal
            choices = [i+1 for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0

        if (coin>=0.6) and (coin<0.8): #right add
            choices = [i for i in range(1,len(old)) if old[i-1] == 1 and old[i] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        if coin>=0.8: #left add
            choices = [i for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        if sum(old)==0:
            choice = np.random.choice(range(len(old)))
            new[choice]=1
        return new


    def acceptance_rate(self,current,new):
        prior = self.PT0(current)
        prior_new = self.PT0(new)
        likl = posterior(self.T,current,self.x,self.y,self.K,self.sigma).likelihood()
        likl_new =posterior(self.T,new,self.x,self.y,self.K,self.sigma).likelihood()
        return (likl_new*prior_new)/(likl*prior)


    def PT0(self,current):
        r=runs(current)
        return mp.exp(-r*self.alpha)

# %%
sigma = 10
T = np.linspace(1, 288, 288)
K = np.fromfunction(np.vectorize(lambda s, t: prior_kernel(T[s], T[t])), (T.shape[0], T.shape[0]), dtype=int)

# %%
df = pd.read_csv('average_curves.csv', index_col='idx')
df
# Out:
#                     0          1          2          3          4          5  \
# idx
# pat_number   0.000000   1.000000   2.000000   3.000000   4.000000   5.000000
# severity     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# constancy    1.000000   1.000000   2.000000   1.000000   2.000000   2.000000
# age         58.000000  59.000000  62.000000  65.000000  65.000000  70.000000
# gender       1.000000   2.000000   2.000000   1.000000   1.000000   2.000000
# ...               ...        ...        ...        ...        ...        ...
# 283         -0.981659  -1.076615  -1.332550  -1.058805  -0.923807  -1.109480
# 284         -0.993531  -1.078280  -1.332549  -1.044116  -0.923762  -1.109441
# 285         -0.997926  -1.079618  -1.332558  -1.019142  -0.923818  -1.109399
# 286         -0.998365  -1.076988  -1.332594  -1.004871  -0.923853  -1.109362
# 287         -0.999580  -1.057946  -1.332677  -1.004709  -0.923863  -1.109328
#
#                     6          7          8          9  ...         150  \
# idx                                                     ...
# pat_number   6.000000   7.000000   8.000000   9.000000  ...  150.000000
# severity     1.000000   1.000000   1.000000   1.000000  ...    3.000000
# constancy    1.000000   1.000000   1.000000   1.000000  ...    3.000000
# age         66.000000  74.000000  58.000000  74.000000  ...   68.000000
# gender       1.000000   1.000000   1.000000   1.000000  ...    2.000000
# ...               ...        ...        ...        ...  ...         ...
# 283         -1.743754  -1.184359  -1.359995  -1.107242  ...   -1.485589
# 284         -1.743714  -1.217882  -1.360021  -1.116414  ...   -1.486356
# 285         -1.743523  -1.224489  -1.360155  -1.127783  ...   -1.487368
# 286         -1.742894  -1.225101  -1.360293  -1.130476  ...   -1.488168
# 287         -1.744557  -1.225101  -1.360323  -1.117656  ...   -1.488808
#
#                    151         152         153         154         155  \
# idx
# pat_number  151.000000  152.000000  153.000000  154.000000  155.000000
# severity      3.000000    3.000000    3.000000    3.000000    3.000000
# constancy     3.000000    3.000000    3.000000    3.000000    3.000000
# age          49.000000   51.000000   66.000000   45.000000   74.000000
# gender        2.000000    1.000000    1.000000    1.000000    1.000000
# ...                ...         ...         ...         ...         ...
# 283          -1.074087   -1.003103   -0.996204   -1.740179   -1.447827
# 284          -1.074077   -1.002612   -0.994606   -1.740226   -1.445859
# 285          -1.074091   -1.003404   -0.994287   -1.740254   -1.440550
# 286          -1.074112   -1.004197   -0.994368   -1.740259   -1.427560
# 287          -1.074124   -1.002548   -0.993982   -1.740229   -1.401408
#
#                    156         157         158         159
# idx
# pat_number  156.000000  157.000000  158.000000  159.000000
# severity      3.000000    3.000000    3.000000    3.000000
# constancy     3.000000    3.000000    3.000000    3.000000
# age          67.000000   59.000000   34.000000   72.000000
# gender        1.000000    2.000000    1.000000    2.000000
# ...                ...         ...         ...         ...
# 283          -1.043098   -1.684661   -1.077221   -1.393487
# 284          -1.042748   -1.684662   -1.077203   -1.393533
# 285          -1.042608   -1.684662   -1.077191   -1.393537
# 286          -1.042606   -1.684661   -1.077185   -1.393493
# 287          -1.042621   -1.684661   -1.077184   -1.393486
#
# [295 rows x 159 columns]

# %%
idxs = np.random.permutation(range(159))[:]
x = df.iloc[7:, idxs].T.to_numpy()
y = df.iloc[1, idxs].T.to_numpy()

y23 = np.copy(y)
y23[y == 1] = 0
y23[y == 2] = 1
y23[y == 3] = 1
np.unique(y23)
# Out:
# array([0., 1.])

# %%
chain = T0_est(T, x, y23, K, sigma, 5, 1000, 100).chain_builder()
# Out:
# Acceptance Rate = 12554.387632583806127903002591812478220827362722896
#
# 1/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 12757.324771142887612982421777751419749610706539309
#
# 2/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 22999.674627851201155528586096103320908819189554983
#
# 3/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 26739.800620595975324549598723182869285990420277137
#
# 4/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 22401.964873955072609556411988495636674494309120679
#
# 5/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.000037405239395956893449108769537733374109709070999798
#
# 6/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 19349.940494344907317867959788594612297093449929195
#
# 7/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 14025.209266488472712427946103853300489945791378366
#
# 8/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 12213.885070912191823621809168358729888937403662232
#
# 9/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 28266.240719133744016367712947761199169147667662732
#
# 10/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 20805.544725993770130976679502292965143996401759635
#
# 11/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 14172.392895350272825773545853614599057613446168638
#
# 12/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 15904.437170936270770085402424703958288885408783538
#
# 13/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 12091.663986896201597108211795513661407974312392392
#
# 14/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 24091.331309139545705102641321811188232585331842745
#
# 15/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 25474.875305501253134652395424900482206455813610677
#
# 16/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 14742.358482597509424002819927684731983878967318905
#
# 17/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 14251.767995914504122311918054911958304642695082942
#
# 18/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 12201.726597112434658550724608830980717490575473152
#
# 19/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 13421.188220653795862065882507699812417381050397078
#
# 20/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 22419.681928948985287880581303632537429956096200441
#
# 21/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 13565.637167675677667925535891575021432762307831674
#
# 22/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 13249.710566941961308554380907331407975053610990578
#
# 23/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000036428677140914227218536543824344621595168139753018
#
# 24/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 0.000044586835990061236032292115626002586558584904841591
#
# 25/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 14819.511892122781410472314191294952553484393408832
#
# 26/1000 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.000044764214501805579127197777670035432446890424052598
#
# 27/1000 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 22567.947606293702546367612168562130690597649824861
#
# 28/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 16048.323119334880620051697214756369254847776796497
#
# 29/1000 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 25663.761073751434534010907355768700543533472366554
#
# 30/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 29118.786561317080429204273865515114850089513391969
#
# 31/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 13861.272323824647527212123165729423775764635691767
#
# 32/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 13753.340179579999186191738540948790121492408164559
#
# 33/1000 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 0.81599755605842760960551286259704114436852091224127
#
# 34/1000 in findind T0...
#
# Current Number of Points in T0: 139
# Acceptance Rate = 23992.893121541294772966511683801381122541120881956
#
# 35/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 14160.396331616620893090236024364469378062772278109
#
# 36/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.000037563131890998297051517466516202789750583746001166
#
# 37/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 14144.220311628840811851168614765207455664058562534
#
# 38/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 22129.754520348923502218825681022149560455990233973
#
# 39/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 12771.698181606763108321307593975468342227040458336
#
# 40/1000 in findind T0...
#
# Current Number of Points in T0: 140
# Acceptance Rate = 22834.958051056690415903428219189946261350474080733
#
# 41/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 26846.995778247775628896633675266984762528159154108
#
# 42/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 0.000044613093895852988088399646044269513253721212546888
#
# 43/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 1.2931852429460633081288065614963287458995326048702
#
# 44/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 12182.563714786652352295702551478168518546934314396
#
# 45/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 28227.205462840182552483877087885096795721681140034
#
# 46/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 22946.03002868813074636550010433563701058054880122
#
# 47/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 0.000062214302319357266814345061239749057099717055698923
#
# 48/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 31046.31429783512902894097201888464895638672739423
#
# 49/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 20271.524561784623479643574071035042847852137766871
#
# 50/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 16728.751174622473064470133417912422860314258863784
#
# 51/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 12750.370502097821354130557908022537516120944393219
#
# 52/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 26116.451661188212516535996462786723603742957985941
#
# 53/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.0000394572183374394614439299155335455622825980307254
#
# 54/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 23654.524825893192832356613303482043078186514620092
#
# 55/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 14762.699210916050959280472987872992480116849959112
#
# 56/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.000044719912899669293676538119637227633248681267612041
#
# 57/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 15795.059610669241146962679078285490873647885542606
#
# 58/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 44511.350463817381512324628206010433985073206095419
#
# 59/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 24079.13830594421799296687301034464065747788742765
#
# 60/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.000041839163846134385934152317976442755149709752464957
#
# 61/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 24911.675355042489820186617502595268597809064555714
#
# 62/1000 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 0.000024306098119897263690180569508700735428915881142754
#
# 63/1000 in findind T0...
#
# Current Number of Points in T0: 147
# Acceptance Rate = 12868.055906178475234177538354347926349288159558386
#
# 64/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 15154.083073135509029289586869956682971158899496475
#
# 65/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 24128.302929490171874465027533717470216960328685786
#
# 66/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 17381.830907682168918260957891060007897001619191407
#
# 67/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 0.000077720982890126465865503818255658307611450640148496
#
# 68/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 33506.685314184194594873066822312506675320853701857
#
# 69/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21476.572447428937517348455091179717455985577976181
#
# 70/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 15173.713389569117708232555249543981888057737699671
#
# 71/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 26507.731351192856765389925016932269376684018128755
#
# 72/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 1.5408327615884426981095131334820961475918930166889
#
# 73/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.57905586467525946737394635639005836830023560761511
#
# 74/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.55724381620902903119028265777321725454517872643812
#
# 75/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 13365.377667432534909983708345344752326075683820656
#
# 76/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 25051.008757644150623791857607417167605735127090627
#
# 77/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 0.7791428375220774619477311673924153806709850621214
#
# 78/1000 in findind T0...
#
# Current Number of Points in T0: 146
# Acceptance Rate = 21949.245803162394243844005981145751192417998553628
#
# 79/1000 in findind T0...
#
# Current Number of Points in T0: 145
# Acceptance Rate = 12393.22632405829967840215179563112122761473603303
#
# 80/1000 in findind T0...
#
# Current Number of Points in T0: 144
# Acceptance Rate = 12370.871043355245385664418156202247643869911863975
#
# 81/1000 in findind T0...
#
# Current Number of Points in T0: 143
# Acceptance Rate = 13353.524390920892474790800177111666895782923330476
#
# 82/1000 in findind T0...
#
# Current Number of Points in T0: 142
# Acceptance Rate = 13148.05247977865885521872753481548155775794654077
#
# 83/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.000037531755718970585841180620863007487472657603450612
#
# 84/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.000041289923189203135089674473343266709311715504512553
#
# 85/1000 in findind T0...
#
# Current Number of Points in T0: 141
# Acceptance Rate = 0.000037249259377371832346399036783637088644662111049629
#
# 86/1000 in findind T0...
#
# Current Number of Points in T0: 141

# %%
T0_hat, counts = stats.mode(chain[200:], axis=0)

# %%
T0_hat

# %%
fitted = posterior(T,T0_hat[0],x,y23,K,sigma).fitted_values()
logit_fitted = scipy.special.expit(fitted)

labels = np.zeros(len(logit_fitted))
ones= np.where(logit_fitted > 0.5)
labels[ones] = np.ones(len(ones))

# %%
print('Accuracy: '+str(sum(labels==y23)/len(labels)))

# %%
m,cov = posterior(T,T0_hat[0],x,y23,K,sigma).posterior_mean_cov()

# %%
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, -0.2, 0.2, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,m,label='Posterior Mean',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, 50, 100, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,np.diag(cov),label='Posterior Covariance Diagonal',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, color in enumerate(['red', 'green']):
    lab = 'T0='+str(i)
    plt.fill_between(T, -2, 5, where=(T0_hat == i), color=color, alpha=0.2, label=lab)

plt.plot(T,x[0,:],label='Observation 0',linewidth=1.3)
plt.plot(T,x[1,:],label='Observation 1',linewidth=1.3)
plt.plot(T,x[2,:],label='Observation 2',linewidth=1.3)
plt.plot(T,x[3,:],label='Observation 3',linewidth=1.3)
plt.xlabel('T')
plt.legend()
plt.grid(True)
plt.show()
