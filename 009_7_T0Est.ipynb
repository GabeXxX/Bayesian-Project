# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats 
import scipy.special
from scipy.special import comb
from scipy.optimize import minimize_scalar

import scipy
import math
import time
from sklearn.gaussian_process.kernels import RBF

from itertools import product, groupby
import random, time

# %%
def runs(a_list):
    runs_zeros = len([k for k, g in groupby(a_list) if k == 0])
    runs_ones = len([k for k, g in groupby(a_list) if k == 1])
    return runs_ones+runs_zeros

# %%
ex = [0,1,1,0,1,0,1]
runs(ex)
# Out:
# 6

# %%
class T0_est:  
    def __init__(self, T, x, y,K,sigma,alpha,n_sim=10000,burn=0):
        self.T= T
        self.x=x
        self.y=y
        self.K=K
        self.sigma=sigma
        self.alpha=alpha
        self.n_sim=n_sim
        self.burn=burn
        self.n = y.shape[0]
        self.g = T.shape[0]
        
        self.T0_init = np.array([0, 1] * (self.g // 2))
        
        self.too_many_rej = 0
        self.action = []
    
    def chain_builder(self):
        chain = [self.T0_init]
        for i in range(self.n_sim):
            curr=chain[-1]
            chain.append(self.next_T0(curr))
        return chain[self.burn:]
    
        
    def next_T0(self,current): 
        new = self.candidate(current)
        rate=self.acceptance_rate(current,new)
        
        if self.too_many_rej ==0:
            treshold = 1
        else:
            treshold = 0.98
            
        if rate>=treshold:
            print("Proposal T0 accepted with rate ", rate)
            self.action.append(1)
            return new
        
        else:
            print("Proposal T0 rejected with rate ", rate)
            self.action.append(0)
            
            if sum(self.action[-10:-1])==0:
                self.too_many_rej = 1
            else:
                self.too_many_rej = 0
                
            return current
        
    def candidate(self,old):
        new=old.copy()
        coin = np.random.uniform(0,1,1)
        
        if coin<0.2: #split
            choices = [i for i in range(1,len(old) - 1) if old[i-1] == 1 and old[i] == 1 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                splitting_point = choice
                new[splitting_point]=0
        
        if (coin>=0.2) and (coin<0.4): #right removal
            choices = [i for i in range(0,len(old)-1) if old[i] == 1 and old[i + 1] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0
        
        if (coin>=0.4) and (coin<0.6): #left removal
            choices = [i+1 for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                removing_point = choice
                new[removing_point]=0
        
        if (coin>=0.6) and (coin<0.8): #right add
            choices = [i for i in range(1,len(old)) if old[i-1] == 1 and old[i] == 0]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        if coin>=0.8: #left add
            choices = [i for i in range(0,len(old)-1) if old[i] == 0 and old[i + 1] == 1]
            if len(choices)>0:
                choice = np.random.choice(choices)
                adding_point = choice
                new[adding_point]=1

        
        return new
        
    
    def acceptance_rate(self,current,new):   
        prior = self.PT0(current)
        prior_new = self.PT0(new)
        likl = posterior(self.T,current,self.x,self.y,self.K,self.sigma).likelihood()
        likl_new =posterior(self.T,new,self.x,self.y,self.K,self.sigma).likelihood()
        
        return (likl_new*prior_new)/(likl*prior)
            
    
    def PT0(self,current): 
        r=runs(current)          
        return np.exp(-self.alpha*r)

# %% [markdown]
# # Class posterior:
# The implementation of this class follows 007_2 notebook with the addition of **likelihood()** method which evaluates p(Y|T0)

# %%
class posterior:
    def __init__(self, T, T0, x, y, K,sigma):
        self.T = T
        self.x = x
        self.y = y
        self.n = y.shape[0]
        self.g = T.shape[0]
        self.T0 = T0
        self.sigma = sigma
        self.K = K
        self.K0 = self.get_K0()
        
    def get_K0(self):
        tau = np.where(self.T0==1)[0]
        print(len(tau))
        K_tau=self.K[:, tau]
        K_tau_tau = self.K[tau[:, None], tau]
        return self.K- K_tau @ np.linalg.inv(K_tau_tau)@ K_tau.T              
        
    def Lx0(self,t):   
        L = np.zeros(self.n)    
        for i in np.arange(0,self.n):
            L[i] = np.trapz(self.K0[t, :] * self.x[i,:], self.T)
        return L
    
    def R0(self,i, j):
        Ri = np.trapz(self.K0[:, :] * self.x[i, :], self.T, axis=1)
        Rij = np.trapz(Ri * self.x[j, :],self.T)
        return Rij

    def M(self):
        return np.array([[self.R0(i, j) for j in range(self.n)] for i in range(self.n)])+np.identity(self.n)
    

    def likelihood(self): #p(Y|T0) 
        m_matrix = self.M()
        first = np.linalg.det(m_matrix) ** (-0.5)

        
        inv = np.linalg.inv(m_matrix)
        s11 = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),np.ones(self.n))
        
        syy = np.dot(np.dot(np.transpose(self.y),inv),self.y)
        s1y = np.dot(np.dot(np.transpose(np.ones(self.n)),inv),self.y)
        b = 0.5*(syy-s1y**2/s11)
            
        return first/np.sqrt(s11)*(b**(-0.5*(n-1)))

# %% [markdown]
# ## Example

# %%
g=128
T = np.linspace(-3,3,g)
T0_real = T[np.where((T >= -1) & (T <= 0.5))]

T0_01 = np.zeros(g)
for i in range(g):
    if (T[i]>=-1) and (T[i]<=0.5):
        T0_01[i]=1


step = T[1]-T[0]
n = 30
alpha = 4
sigma = 0.25

def integrate(T, f): 
    tot = 0;
    for i in range(len(T)-1):
        tot = tot + (1/2 * (f[i]+f[i+1]) * (T[1]-T[0]))
    return tot

def prior_kernel(s,t):
    return np.exp(-2*(t-s)**2)+0.0001*(s==t)

def proj(K,T,T0,f): 
    tau = np.where(T0==1)[0]
    K_tau=K[:, tau]
    K_tau_tau = K[tau[:, None], tau]
    beta_tau = f[tau] 
    
    proj = f-np.dot(K_tau,np.dot(np.linalg.inv(K_tau_tau),beta_tau))
    
    return proj

K = np.zeros((g, g))
K = np.fromfunction(np.vectorize(lambda s, t: prior_kernel(T[s], T[t])), (g, g), dtype=int) 
x = np.random.multivariate_normal(np.zeros(g), K, n)

# %%
beta = np.sin(T*math.pi/4)
beta0 = proj(K,T,T0_01,beta)

y = np.zeros(n)
y = np.fromfunction(np.vectorize(lambda i: integrate(T,  x[i,:]*beta0)+np.random.normal(0,sigma,1)), (n,), dtype=int)

# %%
post = T0_est(T, x, y, K, sigma, alpha, 5000)

chain = post.chain_builder()
# Out:
# 64
# 65
# Proposal T0 accepted with rate  2980.8381234369044
# 65
# 64
# Proposal T0 accepted with rate  2981.058528764342
# 64
# 63
# Proposal T0 rejected with rate  0.0003354758871646607
# 64
# 63
# Proposal T0 accepted with rate  2981.229780189108
# 63
# 62
# Proposal T0 rejected with rate  0.0003354794635989217
# 63
# 62
# Proposal T0 accepted with rate  2981.4713374929856
# 62
# 61
# Proposal T0 rejected with rate  0.00033547947696999715
# 62
# 63
# Proposal T0 accepted with rate  2980.625293424886
# 63
# 64
# Proposal T0 accepted with rate  2980.8692938427776
# 64
# 65
# Proposal T0 accepted with rate  2980.97076114439
# 65
# 64
# Proposal T0 rejected with rate  0.00033546119037279707
# 65
# 66
# Proposal T0 accepted with rate  2980.969311124851
# 66
# 65
# Proposal T0 accepted with rate  2981.6730419123896
# 65
# 66
# Proposal T0 accepted with rate  2980.708625467583
# 66
# 67
# Proposal T0 accepted with rate  2980.8641353407265
# 67
# 66
# Proposal T0 accepted with rate  2981.063445035483
# 66
# 67
# Proposal T0 accepted with rate  2980.985222268166
# 67
# 66
# Proposal T0 rejected with rate  0.00033548067515760623
# 67
# 66
# Proposal T0 rejected with rate  0.00033548067515760623
# 67
# 66
# Proposal T0 rejected with rate  0.0003354907535027053
# 67
# 68
# Proposal T0 accepted with rate  2980.9516180473615
# 68
# 67
# Proposal T0 rejected with rate  0.0003355103453171447
# 68
# 67
# Proposal T0 accepted with rate  2980.923490723644
# 67
# 68
# Proposal T0 accepted with rate  2980.157784081077
# 68
# 69
# Proposal T0 accepted with rate  2980.8744027864673
# 69
# 68
# Proposal T0 accepted with rate  2980.9520635620634
# 68
# 67
# Proposal T0 accepted with rate  2981.3003989730396
# 67
# 66
# Proposal T0 accepted with rate  2980.9100849005263
# 66
# 67
# Proposal T0 accepted with rate  1.0000008267089138
# 67
# 66
# Proposal T0 rejected with rate  0.0003354625399762953
# 67
# 68
# Proposal T0 accepted with rate  2980.885319515677
# 68
# 67
# Proposal T0 rejected with rate  0.0003354611550822028
# 68
# 67
# Proposal T0 rejected with rate  0.0003355063523730621
# 68
# 67
# Proposal T0 rejected with rate  0.0003354910622979977
# 68
# 67
# Proposal T0 accepted with rate  2981.1916571160864
# 67
# 68
# Proposal T0 accepted with rate  2980.8864060899455
# 68
# 69
# Proposal T0 accepted with rate  2980.940791219231
# 69
# 68
# Proposal T0 accepted with rate  2980.8957195771645
# 68
# 67
# Proposal T0 accepted with rate  2981.2976286452176
# 67
# 66
# Proposal T0 accepted with rate  2981.143887861894
# 66
# 65
# Proposal T0 accepted with rate  2980.9931339043587
# 65
# 64
# Proposal T0 accepted with rate  2980.86824137702
# 64
# 65
# Proposal T0 rejected with rate  0.9999032771562225
# 64
# 63
# Proposal T0 rejected with rate  0.00033546998632171817
# 64
# 63
# Proposal T0 accepted with rate  2980.91575257704
# 63
# 62
# Proposal T0 accepted with rate  2982.3931205907215
# 62
# 63
# Proposal T0 rejected with rate  0.9998112797755231
# 62
# 61
# Proposal T0 rejected with rate  0.9999957556140132
# 62
# 63
# Proposal T0 rejected with rate  0.9998615109050765
# 62
# 61
# Proposal T0 accepted with rate  2980.675679339906
# 61
# 60
# Proposal T0 accepted with rate  1.0003073907917277
# 60
# 59
# Proposal T0 accepted with rate  2981.640722960991
# 59
# 58
# Proposal T0 accepted with rate  2980.80680672341
# 58
# 57
# Proposal T0 accepted with rate  2980.9467834408606
# 57
# 56
# Proposal T0 accepted with rate  1.0002018830807349
# 56
# 57
# Proposal T0 accepted with rate  1.0000585746765183
# 57
# 56
# Proposal T0 accepted with rate  2980.8118588142183
# 56
# 57
# Proposal T0 accepted with rate  2980.9243596314145
# 57
# 58
# Proposal T0 rejected with rate  0.9998988179674483
# 57
# 58
# Proposal T0 rejected with rate  0.9998494201515833
# 57
# 58
# Proposal T0 rejected with rate  0.9997974539039648
# 57
# 56
# Proposal T0 rejected with rate  0.0003354740766809607
# 57
# 56
# Proposal T0 rejected with rate  0.00033546949169818257
# 57
# 56
# Proposal T0 rejected with rate  0.0003354515422239675
# 57
# 56
# Proposal T0 rejected with rate  0.00033546143495662514
# 57
# 56
# Proposal T0 rejected with rate  0.9999968480708727
# 57
# 58
# Proposal T0 rejected with rate  0.999897210523248
# 57
# 56
# Proposal T0 accepted with rate  54.60322711936147
# 56
# 55
# Proposal T0 accepted with rate  1.0000016485278036
# 55
# 56
# Proposal T0 accepted with rate  2980.812630502142
# 56
# 57
# Proposal T0 accepted with rate  1.0000056720291992
# 57
# 56
# Proposal T0 rejected with rate  0.00033545634742404904
# 57
# 56
# Proposal T0 rejected with rate  0.999951940452706
# 57
# 56
# Proposal T0 rejected with rate  0.00033554789004531724
# 57
# 56
# Proposal T0 rejected with rate  0.9999968509810643
# 57
# 56
# Proposal T0 accepted with rate  2978.3229797947233
# 56
# 55
# Proposal T0 accepted with rate  1.0002772571357679
# 55
# 54
# Proposal T0 rejected with rate  0.0003355058127278639
# 55
# 54
# Proposal T0 accepted with rate  2982.114612898326
# 54
# 55
# Proposal T0 rejected with rate  0.9997324733227005
# 54
# 53
# Proposal T0 rejected with rate  0.9999977170151138
# 54
# 55
# Proposal T0 rejected with rate  0.999688592661059
# 54
# 53
# Proposal T0 accepted with rate  2981.8694833640966
# 53
# 54
# Proposal T0 accepted with rate  1.0000796589512744
# 54
# 53
# Proposal T0 rejected with rate  0.0003354726594339202
# 54
# 55
# Proposal T0 accepted with rate  2980.512439076682
# 55
# 54
# Proposal T0 rejected with rate  0.00033551109338065
# 55
# 56
# Proposal T0 accepted with rate  1.000015124983041
# 56
# 57
# Proposal T0 accepted with rate  2981.0259693830526
# 57
# 56
# Proposal T0 accepted with rate  1.000268785057755
# 56
# 55
# Proposal T0 rejected with rate  0.0003355018519745399
# 56
# 55
# Proposal T0 rejected with rate  0.0003354597761347794
# 56
# 55
# Proposal T0 accepted with rate  2981.534893317059
# 55
# 56
# Proposal T0 accepted with rate  1.0000471365374846
# 56
# 55
# Proposal T0 rejected with rate  0.00033547100755296737
# 56
# 55
# Proposal T0 rejected with rate  0.9999883927592071
# 56
# 57
# Proposal T0 rejected with rate  0.9995030036961091
# 56
# 55
# Proposal T0 rejected with rate  0.0003354626537643839
# 56
# 57
# Proposal T0 rejected with rate  0.9998286950452427
# 56
# 55
# Proposal T0 accepted with rate  1.0004257035792496
# 55
# 54
# Proposal T0 rejected with rate  0.000335456743132859
# 55
# 54
# Proposal T0 rejected with rate  0.0003354592120049283
# 55
# 54
# Proposal T0 rejected with rate  0.0003354627433123336
# 55
# 54
# Proposal T0 accepted with rate  2988.2231575534042
# 54
# 53
# Proposal T0 rejected with rate  0.9999687437122146
# 54
# 55
# Proposal T0 accepted with rate  2980.96204556843
# 55
# 56
# Proposal T0 accepted with rate  2980.8881670677442
# 56
# 55
# Proposal T0 rejected with rate  0.00033545841963450327
# 56
# 55
# Proposal T0 rejected with rate  0.0003355521017111907
# 56
# 55
# Proposal T0 accepted with rate  2990.0971141083824
# 55
# 54
# Proposal T0 accepted with rate  1.0005546807805947
# 54
# 53
# Proposal T0 accepted with rate  2981.0434600783547
# 53
# 52
# Proposal T0 rejected with rate  0.9999455006899778
# 53
# 52
# Proposal T0 rejected with rate  0.00033545853741911156
# 53
# 52
# Proposal T0 accepted with rate  1.0000455380646505
# 52
# 53
# Proposal T0 rejected with rate  0.9989733239242287
# 52
# 51
# Proposal T0 rejected with rate  0.9991530866747463
# 52
# 53
# Proposal T0 rejected with rate  0.9999583093352905
# 52
# 53
# Proposal T0 accepted with rate  2980.975453896565
# 53
# 54
# Proposal T0 rejected with rate  0.9994471487273772
# 53
# 52
# Proposal T0 accepted with rate  2993.8213810192497
# 52
# 51
# Proposal T0 rejected with rate  0.999137420746185
# 52
# 51
# Proposal T0 rejected with rate  0.00033548498647961977
# 52
# 53
# Proposal T0 rejected with rate  0.9992800754770668
# 52
# 51
# Proposal T0 accepted with rate  1.0000735994151329
# 51
# 50
# Proposal T0 rejected with rate  0.9991375110525901
# 51
# 50
# Proposal T0 accepted with rate  3004.2994037835115
# 50
# 51
# Proposal T0 rejected with rate  0.9968194291760692
# 50
# 51
# Proposal T0 rejected with rate  0.9999767998594064
# 50
# 49
# Proposal T0 accepted with rate  1.0002653783911666
# 49
# 50
# Proposal T0 rejected with rate  0.998185599544527
# 49
# 50
# Proposal T0 rejected with rate  0.9997943483384566
# 49
# 48
# Proposal T0 rejected with rate  0.0003354982158093502
# 49
# 50
# Proposal T0 rejected with rate  0.999810768358578
# 49
# 48
# Proposal T0 rejected with rate  0.0003354931472050786
# 49
# 48
# Proposal T0 rejected with rate  0.9999047088172736
# 49
# 48
# Proposal T0 rejected with rate  0.0003354982158093502
# 49
# 48
# Proposal T0 accepted with rate  1.0022366760068016
# 48
# 49
# Proposal T0 rejected with rate  0.9998121067051353
# 48
# 49
# Proposal T0 accepted with rate  1.0002622772999843
# 49
# 48
# Proposal T0 accepted with rate  3000.1438980412613
# 48
# 49
# Proposal T0 rejected with rate  0.9975759622630325
# 48
# 47
# Proposal T0 rejected with rate  0.9997832887722288
# 48
# 49
# Proposal T0 rejected with rate  0.9999253439420848
# 48
# 47
# Proposal T0 accepted with rate  1.0046993073229413
# 47
# 46
# Proposal T0 accepted with rate  1.0020968522624347
# 46
# 45
# Proposal T0 accepted with rate  1.005341223475537
# 45
# 44
# Proposal T0 accepted with rate  1.002483264333081
# 44
# 43
# Proposal T0 rejected with rate  0.00033551629427597333
# 44
# 45
# Proposal T0 rejected with rate  0.9997856145286557
# 44
# 43
# Proposal T0 rejected with rate  0.9998931902071303
# 44
# 43
# Proposal T0 rejected with rate  0.9998931902071303
# 44
# 45
# Proposal T0 rejected with rate  0.9991011392061505
# 44
# 43
# Proposal T0 rejected with rate  0.999948836259679
# 44
# 45
# Proposal T0 rejected with rate  0.9999493461539135
# 44
# 45
# Proposal T0 rejected with rate  0.9991011392061505
# 44
# 43
# Proposal T0 accepted with rate  1.0016119417280638
# 43
# 44
# Proposal T0 rejected with rate  0.9997918053233198
# 43
# 42
# Proposal T0 rejected with rate  0.00033554685985548953
# 43
# 42
# Proposal T0 rejected with rate  0.00033546384166010965
# 43
# 42
# Proposal T0 rejected with rate  0.0003355251567926014
# 43
# 44
# Proposal T0 rejected with rate  0.9983906524464129
# 43
# 44
# Proposal T0 rejected with rate  0.9997918053233198
# 43
# 42
# Proposal T0 accepted with rate  1.00873681757647
# 42
# 41
# Proposal T0 rejected with rate  0.999962357855163
# 42
# 41
# Proposal T0 accepted with rate  1.00287806064472
# 41
# 42
# Proposal T0 rejected with rate  0.997749558175924
# 41
# 42
# Proposal T0 rejected with rate  0.9971301988171226
# 41
# 40
# Proposal T0 rejected with rate  0.0003355076345064066
# 41
# 40
# Proposal T0 accepted with rate  1.0045227641600079
# 40
# 39
# Proposal T0 accepted with rate  1.0027657381418762
# 39
# 40
# Proposal T0 rejected with rate  0.9946815188574979
# 39
# 38
# Proposal T0 accepted with rate  1.0023167929799577
# 38
# 39
# Proposal T0 rejected with rate  0.9998408324193644
# 38
# 37
# Proposal T0 accepted with rate  1.0065193539314887
# 37
# 36
# Proposal T0 rejected with rate  0.00033544237620840333
# 37
# 36
# Proposal T0 accepted with rate  1.0002468105824023
# 36
# 37
# Proposal T0 rejected with rate  0.9991493558641368
# 36
# 37
# Proposal T0 rejected with rate  0.9947556810702401
# 36
# 35
# Proposal T0 rejected with rate  0.00033564887745918997
# 36
# 35
# Proposal T0 rejected with rate  0.0003354463296265033
# 36
# 37
# Proposal T0 rejected with rate  0.9954809770017087
# 36
# 37
# Proposal T0 rejected with rate  0.9971793251562874
# 36
# 37
# Proposal T0 rejected with rate  0.9961623100630698
# 36
# 35
# Proposal T0 rejected with rate  0.0003354540579050609
# 36
# 35
# Proposal T0 accepted with rate  1.0058266501904183
# 35
# 34
# Proposal T0 accepted with rate  1.0025847409541342
# 34
# 35
# Proposal T0 rejected with rate  0.9953263664644224
# 34
# 35
# Proposal T0 rejected with rate  0.9999674699471791
# 34
# 33
# Proposal T0 accepted with rate  1.0243497063843754
# 33
# 32
# Proposal T0 accepted with rate  1.002311042769128
# 32
# 31
# Proposal T0 rejected with rate  0.0003356014880791027
# 32
# 31
# Proposal T0 rejected with rate  0.00033558917962148556
# 32
# 31
# Proposal T0 accepted with rate  1.0049107039815826
# 31
# 30
# Proposal T0 accepted with rate  1.0062305513929963
# 30
# 31
# Proposal T0 rejected with rate  0.9985580691183155
# 30
# 31
# Proposal T0 rejected with rate  0.9983604184317938
# 30
# 29
# Proposal T0 accepted with rate  1.0071222343220008
# 29
# 28
# Proposal T0 rejected with rate  0.0003356883176413937
# 29
# 28
# Proposal T0 rejected with rate  0.0003357842376392465
# 29
# 30
# Proposal T0 rejected with rate  0.9685972993276308
# 29
# 28
# Proposal T0 accepted with rate  1.0083010850854748
# 28
# 29
# Proposal T0 accepted with rate  1.0013574813748425
# 29
# 28
# Proposal T0 rejected with rate  0.00033573982290129733
# 29
# 28
# Proposal T0 accepted with rate  1.019882244566223
# 28
# 27
# Proposal T0 rejected with rate  0.9986461499256177
# 28
# 27
# Proposal T0 rejected with rate  0.0003353529256494923
# 28
# 27
# Proposal T0 accepted with rate  1.0091610432364575
# 27
# 26
# Proposal T0 rejected with rate  0.9949321266387587
# 27
# 26
# Proposal T0 accepted with rate  3275.8440414598226
# 26
# 25
# Proposal T0 rejected with rate  0.9986870888422372
# 26
# 27
# Proposal T0 rejected with rate  0.9964928959275289
# 26
# 25
# Proposal T0 accepted with rate  1.0003624631523114
# 25
# 26
# Proposal T0 rejected with rate  0.9960400138800714
# 25
# 24
# Proposal T0 rejected with rate  0.9490111964451936
# 25
# 26
# Proposal T0 rejected with rate  0.9945610086363796
# 25
# 24
# Proposal T0 rejected with rate  0.9299775021130261
# 25
# 24
# Proposal T0 accepted with rate  1.0143134249259926
# 24
# 25
# Proposal T0 rejected with rate  0.9938340947514795
# 24
# 25
# Proposal T0 rejected with rate  0.9960084860589655
# 24
# 23
# Proposal T0 rejected with rate  0.9573485567070709
# 24
# 23
# Proposal T0 rejected with rate  0.0003354535859023291
# 24
# 23
# Proposal T0 rejected with rate  0.9986805733080389
# 24
# 25
# Proposal T0 accepted with rate  1.0029161515508855
# 25
# 26
# Proposal T0 rejected with rate  0.9932862845825792
# 25
# 24
# Proposal T0 accepted with rate  1.0076500645542998
# 24
# 23
# Proposal T0 rejected with rate  0.000335464291329091
# 24
# 25
# Proposal T0 rejected with rate  0.9991366832731463
# 24
# 23
# Proposal T0 accepted with rate  1.0181427357248276
# 23
# 22
# Proposal T0 rejected with rate  0.9989993497508466
# 23
# 24
# Proposal T0 accepted with rate  1.0447200756489743
# 24
# 23
# Proposal T0 accepted with rate  1.0010574404675698
# 23
# 22
# Proposal T0 accepted with rate  1.000725653161743
# 22
# 21
# Proposal T0 rejected with rate  0.0003354606888350032
# 22
# 23
# Proposal T0 accepted with rate  1.0011513317692617
# 23
# 22
# Proposal T0 accepted with rate  1.011467678050722
# 22
# 23
# Proposal T0 rejected with rate  0.9950482372819358
# 22
# 21
# Proposal T0 rejected with rate  0.9942463732875648
# 22
# 23
# Proposal T0 rejected with rate  0.9928695603438435
# 22
# 21
# Proposal T0 rejected with rate  0.9033530012351576
# 22
# 21
# Proposal T0 rejected with rate  0.9963145264896338
# 22
# 23
# Proposal T0 rejected with rate  0.9973665832797631
# 22
# 21
# Proposal T0 accepted with rate  3951.915140349482
# 21
# 20
# Proposal T0 accepted with rate  1.0957812723103484
# 20
# 21
# Proposal T0 rejected with rate  0.9914202174361588
# 20
# 21
# Proposal T0 rejected with rate  0.9974396710518665
# 20
# 21
# Proposal T0 rejected with rate  0.9968056198329124
# 20
# 19
# Proposal T0 accepted with rate  8414.38643079308
# 19
# 18
# Proposal T0 rejected with rate  0.00033539710276050933
# 19
# 20
# Proposal T0 rejected with rate  0.9833511432009094
# 19
# 18
# Proposal T0 rejected with rate  0.9902103954537103
# 19
# 20
# Proposal T0 rejected with rate  0.97388269378788
# 19
# 18
# Proposal T0 rejected with rate  0.00033337069588967226
# 19
# 18
# Proposal T0 rejected with rate  0.00033539710276050933
# 19
# 20
# Proposal T0 accepted with rate  1.0218752829777904
# 20
# 19
# Proposal T0 rejected with rate  0.0003355185056449895
# 20
# 21
# Proposal T0 rejected with rate  0.9963414133459078
# 20
# 19
# Proposal T0 rejected with rate  0.989629021571502
# 20
# 21
# Proposal T0 rejected with rate  0.9738039751351208
# 20
# 21
# Proposal T0 rejected with rate  0.9992099163365906
# 20
# 19
# Proposal T0 rejected with rate  0.9785930011791216
# 20
# 21
# Proposal T0 rejected with rate  0.9956500693221382
# 20
# 21
# Proposal T0 rejected with rate  0.9963414133459078
# 20
# 19
# Proposal T0 accepted with rate  1.0951076901449004
# 19
# 20
# Proposal T0 accepted with rate  1.0656735222458784
# 20
# 19
# Proposal T0 rejected with rate  0.7887881059697307
# 20
# 19
# Proposal T0 accepted with rate  1.0457883595795145
# 19
# 20
# Proposal T0 accepted with rate  1.0150991031223815
# 20
# 19
# Proposal T0 rejected with rate  0.7887856607679292
# 20
# 19
# Proposal T0 rejected with rate  0.00033504046935638453
# 20
# 19
# Proposal T0 rejected with rate  0.9906062433137885
# 20
# 21
# Proposal T0 accepted with rate  1.005751823989807
# 21
# 20
# Proposal T0 rejected with rate  0.9431413090834828
# 21
# 20
# Proposal T0 rejected with rate  0.9969852032603828
# 21
# 22
# Proposal T0 accepted with rate  1.0640252866300794
# 22
# 21
# Proposal T0 rejected with rate  0.00033536119735391186
# 22
# 23
# Proposal T0 rejected with rate  0.897058610429949
# 22
# 23
# Proposal T0 rejected with rate  0.9701590639720094
# 22
# 21
# Proposal T0 rejected with rate  0.00033462482626715913
# 22
# 21
# Proposal T0 rejected with rate  0.9969442395359824
# 22
# 21
# Proposal T0 rejected with rate  0.00033550863100624816
# 22
# 21
# Proposal T0 accepted with rate  1.1465781331036187
# 21
# 22
# Proposal T0 accepted with rate  1.0084104095929605
# 22
# 21
# Proposal T0 rejected with rate  0.00033539833410880485
# 22
# 21
# Proposal T0 rejected with rate  0.99813735419147
# 22
# 23
# Proposal T0 rejected with rate  0.9385986072575734
# 22
# 23
# Proposal T0 accepted with rate  1.0397804808979374
# 23
# 22
# Proposal T0 rejected with rate  0.00033556522742437037
# 23
# 22
# Proposal T0 rejected with rate  0.00033447861699143194
# 23
# 24
# Proposal T0 rejected with rate  0.9352074888231438
# 23
# 24
# Proposal T0 accepted with rate  1.0071956440253784
# 24
# 23
# Proposal T0 accepted with rate  1.0004464507625206
# 23
# 22
# Proposal T0 rejected with rate  0.00033571351601640936
# 23
# 24
# Proposal T0 accepted with rate  1.0180040649362774
# 24
# 23
# Proposal T0 accepted with rate  1.0264617101996774
# 23
# 24
# Proposal T0 accepted with rate  1.006513346627802
# 24
# 23
# Proposal T0 rejected with rate  0.9955708650013737
# 24
# 25
# Proposal T0 rejected with rate  0.8160625485691653
# 24
# 25
# Proposal T0 rejected with rate  0.9339717455890014
# 24
# 23
# Proposal T0 accepted with rate  246923.22892342263
# 23
# 22
# Proposal T0 accepted with rate  1.00140455086798
# 22
# 21
# Proposal T0 rejected with rate  0.00033508310660584423
# 22
# 21
# Proposal T0 rejected with rate  0.0003336013144825278
# 22
# 23
# Proposal T0 accepted with rate  1.0277515838492381
# 23
# 24
# Proposal T0 accepted with rate  1.00292672714754
# 24
# 23
# Proposal T0 rejected with rate  0.9859053187822063
# 24
# 25
# Proposal T0 accepted with rate  1.0086791518923546
# 25
# 24
# Proposal T0 rejected with rate  0.00033504251905518763
# 25
# 26
# Proposal T0 rejected with rate  0.8423719467717987
# 25
# 24
# Proposal T0 rejected with rate  0.9859851315027259
# 25
# 24
# Proposal T0 accepted with rate  45740.730359568384
# 24
# 23
# Proposal T0 accepted with rate  1.0376862128059603
# 23
# 22
# Proposal T0 rejected with rate  0.9941270685387742
# 23
# 24
# Proposal T0 rejected with rate  0.44280191151731074
# 23
# 24
# Proposal T0 accepted with rate  1.0439528055039908
# 24
# 25
# Proposal T0 rejected with rate  0.7331197737714323
# 24
# 23
# Proposal T0 accepted with rate  1.612697708684937
# 23
# 22
# Proposal T0 rejected with rate  0.00033551102767971066
# 23
# 24
# Proposal T0 accepted with rate  1.0356997831552783
# 24
# 25
# Proposal T0 rejected with rate  0.8458936808744308
# 24
# 23
# Proposal T0 rejected with rate  0.0003353536022826487
# 24
# 23
# Proposal T0 rejected with rate  0.9655307611955675
# 24
# 23
# Proposal T0 accepted with rate  2.5090864724555426
# 23
# 22
# Proposal T0 accepted with rate  1.096431758105818
# 22
# 21
# Proposal T0 rejected with rate  0.9857453165031578
# 22
# 21
# Proposal T0 accepted with rate  1684196646.7243135
# 21
# 20
# Proposal T0 accepted with rate  2215.7134412536507
# 20
# 21
# Proposal T0 rejected with rate  0.9683017959235544
# 20
# 21
# Proposal T0 accepted with rate  1.0887747343145544
# 21
# 22
# Proposal T0 rejected with rate  0.5706334789720997
# 21
# 22
# Proposal T0 rejected with rate  0.9727459498905461
# 21
# 20
# Proposal T0 accepted with rate  1.4032739695364334
# 20
# 21
# Proposal T0 rejected with rate  0.349068950564937
# 20
# 21
# Proposal T0 rejected with rate  0.349068950564937
# 20
# 19
# Proposal T0 rejected with rate  0.0003352775727717108
# 20
# 19
# Proposal T0 rejected with rate  0.0003346312846178935
# 20
# 19
# Proposal T0 accepted with rate  1.5647407344969348
# 19
# 18
# Proposal T0 rejected with rate  0.9134185956943223
# 19
# 20
# Proposal T0 accepted with rate  1.0848742182109168
# 20
# 19
# Proposal T0 accepted with rate  1.951232099450665
# 19
# 18
# Proposal T0 accepted with rate  1.0391536524028147
# 18
# 19
# Proposal T0 rejected with rate  0.9919013667086298
# 18
# 17
# Proposal T0 accepted with rate  1.002690822499344
# 17
# 16
# Proposal T0 rejected with rate  0.00035090875036045854
# 17
# 16
# Proposal T0 accepted with rate  1.063973435918354
# 16
# 17
# Proposal T0 rejected with rate  0.9664548299024546
# 16
# 15
# Proposal T0 rejected with rate  0.0003423956451625803
# 16
# 17
# Proposal T0 rejected with rate  0.5605439913347998
# 16
# 17
# Proposal T0 rejected with rate  0.4746430829065364
# 16
# 15
# Proposal T0 rejected with rate  0.0003354900075587009
# 16
# 15
# Proposal T0 accepted with rate  747700.8003564411
# 15
# 14
# Proposal T0 accepted with rate  1.048445685958314
# 14
# 13
# Proposal T0 accepted with rate  1.0281164449482063
# 13
# 14
# Proposal T0 rejected with rate  0.9347388560869145
# 13
# 12
# Proposal T0 accepted with rate  1.0544730453979332
# 12
# 11
# Proposal T0 rejected with rate  0.9999007167090649
# 12
# 13
# Proposal T0 accepted with rate  1.0311025100758526
# 13
# 12
# Proposal T0 rejected with rate  0.00034212899444004304
# 13
# 14
# Proposal T0 rejected with rate  0.9620895726989764
# 13
# 12
# Proposal T0 rejected with rate  0.0003458250551382427
# 13
# 14
# Proposal T0 rejected with rate  0.9620895726989764
# 13
# 12
# Proposal T0 accepted with rate  1.0532519817269923
# 12
# 13
# Proposal T0 rejected with rate  0.9359612002176585
# 12
# 11
# Proposal T0 rejected with rate  0.0003362746766888326
# 12
# 11
# Proposal T0 accepted with rate  1.0341343574463453
# 11
# 12
# Proposal T0 rejected with rate  0.9669923378905662
# 11
# 10
# Proposal T0 rejected with rate  0.0003471394528123212
# 11
# 12
# Proposal T0 rejected with rate  0.49182241702202445
# 11
# 12
# Proposal T0 rejected with rate  0.9669923378905662
# 11
# 10
# Proposal T0 rejected with rate  0.0003689002478467336
# 11
# 10
# Proposal T0 accepted with rate  1.0214150569430356
# 10
# 9
# Proposal T0 rejected with rate  0.00034870696525401886
# 10
# 11
# Proposal T0 rejected with rate  0.4850547210339272
# 10
# 9
# Proposal T0 accepted with rate  1.6156558032908734
# 9
# 8
# Proposal T0 rejected with rate  0.9734676437231485
# 9
# 10
# Proposal T0 rejected with rate  0.9843145384098246
# 9
# 8
# Proposal T0 rejected with rate  0.9734676437231485
# 9
# 8
# Proposal T0 rejected with rate  0.0003412682207156501
# 9
# 8
# Proposal T0 rejected with rate  0.9734676437231485
# 9
# 8
# Proposal T0 rejected with rate  0.0003551147549137348
# 9
# 8
# Proposal T0 rejected with rate  0.9734676437231485
# 9
# 8
# Proposal T0 rejected with rate  0.9734676437231485
# 9
# 8
# Proposal T0 accepted with rate  1.3727494492611696
# 8
# 9
# Proposal T0 rejected with rate  0.7284650527728946
# 8
# 7
# Proposal T0 rejected with rate  0.801460310549878
# 8
# 9
# Proposal T0 rejected with rate  0.7284650527728946
# 8
# 7
# Proposal T0 accepted with rate  1.2520177391875096
# 7
# 6
# Proposal T0 rejected with rate  0.7817642592945987
# 7
# 6
# Proposal T0 accepted with rate  1.1482468465977187
# 6
# 7
# Proposal T0 accepted with rate  1.0635827651496386
# 7
# 6
# Proposal T0 rejected with rate  0.00032920209257219916
# 7
# 8
# Proposal T0 accepted with rate  1.023783289139617
# 8
# 9
# Proposal T0 rejected with rate  0.8693911407169483
# 8
# 9
# Proposal T0 rejected with rate  0.8693911407169483
# 8
# 7
# Proposal T0 rejected with rate  0.9400650205480876
# 8
# 7
# Proposal T0 accepted with rate  1.0041201299969198
# 7
# 8
# Proposal T0 rejected with rate  0.9958967758201077
# 7
# 6
# Proposal T0 rejected with rate  0.00033883743599119614
# 7
# 6
# Proposal T0 rejected with rate  0.9624724625863516
# 7
# 6
# Proposal T0 accepted with rate  1.0492925913130051
# 6
# 5
# Proposal T0 rejected with rate  0.9511496899252652
# 6
# 7
# Proposal T0 accepted with rate  1.0512680241646872
# 7
# 8
# Proposal T0 accepted with rate  1.0634583964473667
# 8
# 7
# Proposal T0 rejected with rate  0.0003327462869205675
# 8
# 7
# Proposal T0 rejected with rate  0.9403282755024941
# 8
# 9
# Proposal T0 rejected with rate  0.9384045424498005
# 8
# 9
# Proposal T0 accepted with rate  1.0722446598494348
# 9
# 8
# Proposal T0 rejected with rate  0.9744053003905659
# 9
# 10
# Proposal T0 accepted with rate  1.0632102429896604
# 10
# 9
# Proposal T0 rejected with rate  0.940547748287377
# 10
# 9
# Proposal T0 rejected with rate  0.00033276768507964154
# 10
# 11
# Proposal T0 rejected with rate  0.8972443212328529
# 10
# 9
# Proposal T0 rejected with rate  0.9971465231704376
# 10
# 11
# Proposal T0 rejected with rate  0.8972443212328529
# 10
# 11
# Proposal T0 accepted with rate  1.027236165401285
# 11
# 12
# Proposal T0 rejected with rate  0.9910588817196149
# 11
# 10
# Proposal T0 accepted with rate  1.011959860299742
# 10
# 9
# Proposal T0 accepted with rate  1.0127715491977392
# 9
# 10
# Proposal T0 accepted with rate  1.0160602782695323
# 10
# 9
# Proposal T0 accepted with rate  1.032027143162301
# 9
# 10
# Proposal T0 accepted with rate  1.0401439608243477
# 10
# 11
# Proposal T0 rejected with rate  0.9499401108708521
# 10
# 9
# Proposal T0 rejected with rate  0.9614053800855293
# 10
# 9
# Proposal T0 rejected with rate  0.9614053800855293
# 10
# 11
# Proposal T0 accepted with rate  1.011851457164763
# 11
# 10
# Proposal T0 rejected with rate  0.0003387699933688852
# 11
# 12
# Proposal T0 rejected with rate  0.9503766621298398
# 11
# 10
# Proposal T0 rejected with rate  0.9733679288940087
# 11
# 10
# Proposal T0 accepted with rate  1.033600050014141
# 10
# 9
# Proposal T0 rejected with rate  0.952443793783793
# 10
# 9
# Proposal T0 accepted with rate  1.030014564870166
# 9
# 8
# Proposal T0 rejected with rate  0.9534437303700506
# 9
# 8
# Proposal T0 rejected with rate  0.9619537218976821
# 9
# 10
# Proposal T0 accepted with rate  1.008779049073071
# 10
# 11
# Proposal T0 rejected with rate  0.9814311776767928
# 10
# 11
# Proposal T0 rejected with rate  0.9814311776767928
# 10
# 9
# Proposal T0 rejected with rate  0.9515126411859373
# 10
# 11
# Proposal T0 rejected with rate  0.9814311776767928
# 10
# 9
# Proposal T0 rejected with rate  0.00033635472927104186
# 10
# 9
# Proposal T0 rejected with rate  0.9515126411859373
# 10
# 9
# Proposal T0 rejected with rate  0.9947707610500955
# 10
# 9
# Proposal T0 accepted with rate  1.0086975328471346
# 9
# 8
# Proposal T0 rejected with rate  0.00033704376932043535
# 9
# 10
# Proposal T0 rejected with rate  0.9359678017765508
# 9
# 10
# Proposal T0 rejected with rate  0.9766159744069824
# 9
# 8
# Proposal T0 rejected with rate  0.6932008941260803
# 9
# 8
# Proposal T0 rejected with rate  0.6932008941260803
# 9
# 8
# Proposal T0 rejected with rate  0.9934137955759667
# 9
# 10
# Proposal T0 rejected with rate  0.9913774619606879
# 9
# 8
# Proposal T0 rejected with rate  0.9928165298126586
# 9
# 10
# Proposal T0 rejected with rate  0.9766159744069824
# 9
# 8
# Proposal T0 rejected with rate  0.9928165298126586
# 9
# 10
# Proposal T0 rejected with rate  0.9766159744069824
# 9
# 8
# Proposal T0 rejected with rate  0.6932008941260803
# 9
# 8
# Proposal T0 accepted with rate  0.9934137955759667
# 8
# 7
# Proposal T0 rejected with rate  0.7148307343693827
# 8
# 7
# Proposal T0 rejected with rate  0.9567405750337562
# 8
# 9
# Proposal T0 rejected with rate  0.9927316458805218
# 8
# 7
# Proposal T0 rejected with rate  0.6920413333447655
# 8
# 9
# Proposal T0 accepted with rate  1.0466583330448918
# 9
# 10
# Proposal T0 rejected with rate  0.9723171762321384
# 9
# 10
# Proposal T0 accepted with rate  1.004316120520165
# 10
# 9
# Proposal T0 accepted with rate  1.0425249362021105
# 9
# 8
# Proposal T0 accepted with rate  1.0090590745917363
# 8
# 9
# Proposal T0 rejected with rate  0.9910222554656658
# 8
# 9
# Proposal T0 accepted with rate  1.0034470347109143
# 9
# 8
# Proposal T0 rejected with rate  0.0003337550734968511
# 9
# 8
# Proposal T0 rejected with rate  0.9965648065202491
# 9
# 8
# Proposal T0 rejected with rate  0.6683068968491686
# 9
# 10
# Proposal T0 rejected with rate  0.9244213776035531
# 9
# 10
# Proposal T0 accepted with rate  1.0235811200056526
# 10
# 9
# Proposal T0 accepted with rate  1.0082976054459205
# 9
# 8
# Proposal T0 rejected with rate  0.9997307351629364
# 9
# 10
# Proposal T0 rejected with rate  0.9917706782193032
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 8
# Proposal T0 rejected with rate  0.9997307351629364
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.9997307351629364
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 10
# Proposal T0 rejected with rate  0.9917706782193032
# 9
# 8
# Proposal T0 accepted with rate  0.989894237486218
# 8
# 7
# Proposal T0 rejected with rate  0.9549614328987374
# 8
# 7
# Proposal T0 rejected with rate  0.6189097092842097
# 8
# 7
# Proposal T0 rejected with rate  0.9296767219732186
# 8
# 7
# Proposal T0 rejected with rate  0.00033185885659278854
# 8
# 7
# Proposal T0 rejected with rate  0.9296767219732186
# 8
# 7
# Proposal T0 rejected with rate  0.6189097092842097
# 8
# 9
# Proposal T0 rejected with rate  0.9625670907840345
# 8
# 7
# Proposal T0 rejected with rate  0.9296767219732186
# 8
# 7
# Proposal T0 rejected with rate  0.6189097092842097
# 8
# 7
# Proposal T0 rejected with rate  0.9296767219732186
# 8
# 7
# Proposal T0 rejected with rate  0.6238703145743567
# 8
# 7
# Proposal T0 rejected with rate  0.0003369027221573319
# 8
# 9
# Proposal T0 accepted with rate  1.0102089315515617
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 8
# Proposal T0 rejected with rate  0.000337845866145301
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 10
# Proposal T0 rejected with rate  0.9917706782193032
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 8
# Proposal T0 rejected with rate  0.0003377839972803783
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 10
# Proposal T0 accepted with rate  0.9917706782193032
# 10
# 11
# Proposal T0 rejected with rate  0.9646801008707646
# 10
# 9
# Proposal T0 rejected with rate  0.9995190875916281
# 10
# 9
# Proposal T0 rejected with rate  0.9769621385694156
# 10
# 9
# Proposal T0 accepted with rate  1.0082976054459205
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 8
# Proposal T0 rejected with rate  0.00033365468013345266
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 8
# Proposal T0 rejected with rate  0.6475375242785619
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.6453669644485219
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 8
# Proposal T0 accepted with rate  0.9997307351629364
# 8
# 7
# Proposal T0 rejected with rate  0.0003311204179879882
# 8
# 7
# Proposal T0 rejected with rate  0.9341772619956057
# 8
# 7
# Proposal T0 rejected with rate  0.00033659292122266595
# 8
# 7
# Proposal T0 rejected with rate  0.0003363578197226909
# 8
# 9
# Proposal T0 accepted with rate  1.000269337360144
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 10
# Proposal T0 rejected with rate  0.9629920973990963
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 10
# Proposal T0 rejected with rate  0.9178885213518637
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 8
# Proposal T0 rejected with rate  0.989894237486218
# 9
# 8
# Proposal T0 rejected with rate  0.9997307351629364
# 9
# 10
# Proposal T0 accepted with rate  1.0081475839955758
# 10
# 11
# Proposal T0 rejected with rate  0.9635230840471606
# 10
# 11
# Proposal T0 rejected with rate  0.9635230840471606
# 10
# 11
# Proposal T0 rejected with rate  0.9021350297662835
# 10
# 11
# Proposal T0 rejected with rate  0.9021350297662835
# 10
# 11
# Proposal T0 rejected with rate  0.9228293978005361
# 10
# 9
# Proposal T0 rejected with rate  0.0003377644850668707
# 10
# 9
# Proposal T0 rejected with rate  0.0003391243129971907
# 10
# 11
# Proposal T0 rejected with rate  0.9145330337150924
# 10
# 11
# Proposal T0 rejected with rate  0.9228293978005361
# 10
# 9
# Proposal T0 accepted with rate  1.0032044180183726
# 9
# 10
# Proposal T0 rejected with rate  0.996805817477656
# 9
# 8
# Proposal T0 rejected with rate  0.9884836590810122
# 9
# 8
# Proposal T0 rejected with rate  0.9366118210882519
# 9
# 10
# Proposal T0 accepted with rate  1.0010987094486152
# 10
# 9
# Proposal T0 rejected with rate  0.00033792119330796667
# 10
# 11
# Proposal T0 rejected with rate  0.9593913231405682
# 10
# 9
# Proposal T0 rejected with rate  0.00034112238773278936
# 10
# 9
# Proposal T0 rejected with rate  0.9753010214526228
# 10
# 9
# Proposal T0 rejected with rate  0.00034112238773278936
# 10
# 9
# Proposal T0 rejected with rate  0.987656898275869
# 10
# 11
# Proposal T0 rejected with rate  0.9305099267542879
# 10
# 11
# Proposal T0 rejected with rate  0.9150122943014211
# 10
# 9
# Proposal T0 accepted with rate  1.009435471166362
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 8
# Proposal T0 accepted with rate  0.9961416173252732
# 8
# 7
# Proposal T0 rejected with rate  0.6262301169643292
# 8
# 7
# Proposal T0 rejected with rate  0.9369703577963644
# 8
# 9
# Proposal T0 accepted with rate  1.00387332745427
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 8
# Proposal T0 rejected with rate  0.0003337385456936828
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.000335622409122375
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 11
# Proposal T0 rejected with rate  0.9639470354749635
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 rejected with rate  0.00033583023690332596
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.9639470354749635
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 11
# Proposal T0 rejected with rate  0.9639470354749635
# 10
# 9
# Proposal T0 rejected with rate  0.0003336996680479498
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 9
# Proposal T0 accepted with rate  1.0087115030200093
# 9
# 8
# Proposal T0 rejected with rate  0.0003382756962567062
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 9
# Proposal T0 accepted with rate  0.9904267440195721
# 9
# 8
# Proposal T0 rejected with rate  0.00033818679487250926
# 9
# 8
# Proposal T0 rejected with rate  0.00033729835383533943
# 9
# 10
# Proposal T0 rejected with rate  0.9982221532258704
# 9
# 8
# Proposal T0 rejected with rate  0.6148371587467564
# 9
# 10
# Proposal T0 rejected with rate  0.9684432291666243
# 9
# 10
# Proposal T0 rejected with rate  0.9053347212330815
# 9
# 8
# Proposal T0 rejected with rate  0.9722038944070552
# 9
# 10
# Proposal T0 rejected with rate  0.9701415151671349
# 9
# 10
# Proposal T0 rejected with rate  0.9701415151671349
# 9
# 8
# Proposal T0 accepted with rate  1.0096657890532879
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 accepted with rate  0.9904267440195721
# 9
# 10
# Proposal T0 accepted with rate  0.9982221532258704
# 10
# 9
# Proposal T0 accepted with rate  1.0017810131426
# 9
# 10
# Proposal T0 rejected with rate  0.9701415151671349
# 9
# 8
# Proposal T0 rejected with rate  0.6322357734044782
# 9
# 10
# Proposal T0 rejected with rate  0.9982221532258704
# 9
# 8
# Proposal T0 accepted with rate  1.0096657890532879
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 7
# Proposal T0 rejected with rate  0.00033675877992444864
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 7
# Proposal T0 rejected with rate  0.00033673964203407306
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 7
# Proposal T0 rejected with rate  0.0003317847603983085
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 7
# Proposal T0 rejected with rate  0.00033675877992444864
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 9
# Proposal T0 accepted with rate  0.9941774141463081
# 9
# 8
# Proposal T0 accepted with rate  1.0065900330601907
# 8
# 7
# Proposal T0 rejected with rate  0.0003367114576116738
# 8
# 7
# Proposal T0 rejected with rate  0.0003323281525467765
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 7
# Proposal T0 rejected with rate  0.6338494820587031
# 8
# 9
# Proposal T0 accepted with rate  1.00387332745427
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 9
# Proposal T0 rejected with rate  0.00033720793708757714
# 10
# 9
# Proposal T0 rejected with rate  0.0003336996680479498
# 10
# 11
# Proposal T0 rejected with rate  0.9639470354749635
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 9
# Proposal T0 rejected with rate  0.0003336996680479498
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 9
# Proposal T0 rejected with rate  0.00033770520982725284
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 9
# Proposal T0 rejected with rate  0.00033583023690332596
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.000335622409122375
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 9
# Proposal T0 accepted with rate  0.9941774141463081
# 9
# 10
# Proposal T0 rejected with rate  0.8703533649825032
# 9
# 10
# Proposal T0 rejected with rate  0.8703533649825032
# 9
# 10
# Proposal T0 rejected with rate  0.9919550775198837
# 9
# 8
# Proposal T0 rejected with rate  0.935489084660704
# 9
# 8
# Proposal T0 rejected with rate  0.0003441160988460123
# 9
# 8
# Proposal T0 accepted with rate  1.0065900330601907
# 8
# 7
# Proposal T0 rejected with rate  0.0003311214477455615
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 9
# Proposal T0 rejected with rate  0.9959037614509305
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 7
# Proposal T0 rejected with rate  0.6338494820587031
# 8
# 9
# Proposal T0 rejected with rate  0.9959037614509305
# 8
# 7
# Proposal T0 rejected with rate  0.6262301169643292
# 8
# 9
# Proposal T0 rejected with rate  0.9959037614509305
# 8
# 9
# Proposal T0 rejected with rate  0.993398390977595
# 8
# 7
# Proposal T0 rejected with rate  0.9346195860684426
# 8
# 7
# Proposal T0 rejected with rate  0.6262301169643292
# 8
# 9
# Proposal T0 accepted with rate  0.9934531111537475
# 9
# 10
# Proposal T0 rejected with rate  0.908368643889318
# 9
# 8
# Proposal T0 accepted with rate  1.0033268674842832
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.0003360090278957945
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.0003382756962567062
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.0003360090278957945
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# ...
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.0003382756962567062
# 9
# 8
# Proposal T0 rejected with rate  0.0003374031912230754
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 9
# Proposal T0 rejected with rate  0.00033720793708757714
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 9
# Proposal T0 rejected with rate  0.00033720793708757714
# 10
# 9
# Proposal T0 accepted with rate  1.0087115030200093
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.0003374031912230754
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.0003360090278957945
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.0003317847603983085
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.0003374031912230754
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.0003374031912230754
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.0003360090278957945
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 9
# Proposal T0 rejected with rate  0.0003336996680479498
# 10
# 11
# Proposal T0 rejected with rate  0.9639470354749635
# 10
# 11
# Proposal T0 rejected with rate  0.9528802552322121
# 10
# 9
# Proposal T0 rejected with rate  0.9941774141463081
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 10
# Proposal T0 accepted with rate  0.9906527247794654
# 10
# 11
# Proposal T0 rejected with rate  0.9305099267542879
# 10
# 9
# Proposal T0 accepted with rate  1.009435471166362
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 8
# Proposal T0 rejected with rate  0.000335622409122375
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.0003337385456936828
# 9
# 8
# Proposal T0 rejected with rate  0.0003381044341299315
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.6534445806350777
# 9
# 10
# Proposal T0 accepted with rate  0.9906527247794654
# 10
# 9
# Proposal T0 accepted with rate  0.9989024963889722
# 9
# 10
# Proposal T0 accepted with rate  1.0010987094486152
# 10
# 9
# Proposal T0 accepted with rate  1.009435471166362
# 9
# 8
# Proposal T0 accepted with rate  0.9961416173252732
# 8
# 7
# Proposal T0 rejected with rate  0.9369703577963644
# 8
# 7
# Proposal T0 rejected with rate  0.0003367114576116738
# 8
# 9
# Proposal T0 rejected with rate  0.9934531111537475
# 8
# 9
# Proposal T0 rejected with rate  0.9959037614509305
# 8
# 7
# Proposal T0 rejected with rate  0.9369703577963644
# 8
# 7
# Proposal T0 rejected with rate  0.0003365592015448618
# 8
# 7
# Proposal T0 rejected with rate  0.0003365592015448618
# 8
# 7
# Proposal T0 rejected with rate  0.0003367114576116738
# 8
# 9
# Proposal T0 rejected with rate  0.9934531111537475
# 8
# 9
# Proposal T0 rejected with rate  0.9934531111537475
# 8
# 9
# Proposal T0 accepted with rate  0.9934531111537475
# 9
# 8
# Proposal T0 rejected with rate  0.935489084660704
# 9
# 8
# Proposal T0 accepted with rate  1.0033268674842832
# 8
# 9
# Proposal T0 rejected with rate  0.9904267440195721
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 9
# Proposal T0 rejected with rate  0.00034384007870162143
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.000337800411679288
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 11
# Proposal T0 rejected with rate  0.910633874487739
# 10
# 9
# Proposal T0 rejected with rate  0.0003381414639598883
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 9
# Proposal T0 rejected with rate  0.00033770520982725284
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 9
# Proposal T0 rejected with rate  0.0003381414639598883
# 10
# 9
# Proposal T0 rejected with rate  0.00033770520982725284
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 8
# Proposal T0 rejected with rate  0.000335622409122375
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9566242069636555
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 8
# Proposal T0 rejected with rate  0.6590579690350706
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 11
# Proposal T0 rejected with rate  0.8762718476469886
# 10
# 9
# Proposal T0 accepted with rate  1.0087115030200093
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 10
# Proposal T0 accepted with rate  0.9913637318560087
# 10
# 9
# Proposal T0 rejected with rate  0.9785656261791984
# 10
# 9
# Proposal T0 accepted with rate  1.004605227578255
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.0003337385456936828
# 9
# 8
# Proposal T0 rejected with rate  0.0003371231208879403
# 9
# 10
# Proposal T0 rejected with rate  0.9906527247794654
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 10
# Proposal T0 rejected with rate  0.9632042905780672
# 9
# 10
# Proposal T0 rejected with rate  0.9954158833222909
# 9
# 8
# Proposal T0 rejected with rate  0.9754447848848389
# 9
# 8
# Proposal T0 rejected with rate  0.9961416173252732
# 9
# 10
# Proposal T0 accepted with rate  0.9954158833222909
# 10
# 9
# Proposal T0 accepted with rate  1.0087115030200093
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9643127114009955
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 9
# Proposal T0 rejected with rate  0.9727357155970264
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.9263643104423486
# 8
# 9
# Proposal T0 rejected with rate  0.9966841638631437
# 8
# 7
# Proposal T0 rejected with rate  0.00033122690676523105
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 8
# Proposal T0 rejected with rate  0.6366671069048424
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 10
# Proposal T0 rejected with rate  0.975550326667958
# 9
# 10
# Proposal T0 rejected with rate  0.9501601452201992
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 10
# Proposal T0 rejected with rate  0.9913637318560087
# 9
# 8
# Proposal T0 rejected with rate  0.0003376741625626074
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.0003336040285223585
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 accepted with rate  0.9888703635010035
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.00033675877992444864
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.6132521495608836
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.00033675877992444864
# 8
# 7
# Proposal T0 rejected with rate  0.628266833638127
# 8
# 7
# Proposal T0 rejected with rate  0.9364277831841741
# 8
# 7
# Proposal T0 rejected with rate  0.00033675877992444864
# 8
# 9
# Proposal T0 accepted with rate  1.0112548994385806
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.9792490441661253
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8
# Proposal T0 rejected with rate  0.9888703635010035
# 9
# 8
# Proposal T0 rejected with rate  0.6507845302381349
# 9
# 8

# %%
plt.plot(T,post.T0_init,label='Initialization of T0')
plt.plot(T,1.5*np.array(chain[-1]),label='Last T0 of the Chain')
plt.plot(T,2*T0_01,label='True T0')
plt.legend()

# %%
T0_hat, counts = stats.mode(chain, axis=0)
idxs = np.where(T0_hat==1)

# %%
idxs

# %%
T[idxs[1][0]]
