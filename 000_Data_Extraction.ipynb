# %%
import pandas as pd

# %%
# filename paxraw_c.xpt

# %%
df = pd.read_sas('paxraw_c.xpt',iterator=False)
df
# Out:
#              SEQN  PAXSTAT  PAXCAL  PAXDAY     PAXN       PAXHOUR  \
# 0         21005.0      1.0     1.0     1.0      1.0  5.397605e-79
# 1         21005.0      1.0     1.0     1.0      2.0  5.397605e-79
# 2         21005.0      1.0     1.0     1.0      3.0  5.397605e-79
# 3         21005.0      1.0     1.0     1.0      4.0  5.397605e-79
# 4         21005.0      1.0     1.0     1.0      5.0  5.397605e-79
# ...           ...      ...     ...     ...      ...           ...
# 72250022  31125.0      1.0     1.0     2.0  10076.0  2.300000e+01
# 72250023  31125.0      1.0     1.0     2.0  10077.0  2.300000e+01
# 72250024  31125.0      1.0     1.0     2.0  10078.0  2.300000e+01
# 72250025  31125.0      1.0     1.0     2.0  10079.0  2.300000e+01
# 72250026  31125.0      1.0     1.0     2.0  10080.0  2.300000e+01
#
#               PAXMINUT      PAXINTEN
# 0         5.397605e-79  5.397605e-79
# 1         1.000000e+00  5.397605e-79
# 2         2.000000e+00  5.397605e-79
# ...
