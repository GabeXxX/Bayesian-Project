# %%
import scipy
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = scipy.io.loadmat('TremorStruct_V1_Joint_Severity_Constancy_After_Exclusion.mat')

# %%
print(df.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'TremorStruct', '__function_workspace__'])

# %%
var = df['TremorStruct'][0]

# %%
day1_pat1 = var[0][17][0,0][0][:,0]
day2_pat1 = var[0][17][0,0][0][:,1]
day3_pat1 = var[0][17][0,0][0][:,2]
plt.plot(day1_pat1, label='Day 1',c='#f4963e')
plt.plot(day2_pat1, label='Day 2',c='#3399ff')
plt.title('Individual #1 in Different Days')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
plt.plot(day1_pat1, label='Day 1',c='#62a87c')
plt.plot(day2_pat1, label='Day 2',c='#f94e56')
plt.title('Individual #1 in Different Days')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
plt.plot(day1_pat1, label='Day 1',c='#3399ff')
plt.title('Individual #1 in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
plt.plot(day1_pat1, label='Day 1',c='#f4963e')
plt.title('Individual #1 in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
plt.plot(day1_pat1, label='Day 1',c='#62a87c')
plt.title('Individual #1 in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
plt.plot(day1_pat1, label='Day 1',c='#f94e56')
plt.title('Individual #1 in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
day1_pat1 = var[0][17][0,0][0][:,0]
day1_pat2 = var[1][17][0,0][0][:,0]
day1_pat3 = var[2][17][0,0][0][:,0]
plt.plot(day1_pat1, label='Individual 1',c='#f4963e')
plt.plot(day2_pat1, label='Individual 2',c='#3399ff')
plt.title('Different Individuals in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()

# %%
ax, fig = plt.sub
plt.plot(day1_pat1, label='Individual 1',c='#f4963e')
plt.plot(day2_pat1, label='Individual 2',c='#62a87c')
plt.title('Different Individuals in Day #1')
plt.ylabel('Tremor Probability (Zscore)')
plt.xlabel('Observation within the Day')
plt.legend()
